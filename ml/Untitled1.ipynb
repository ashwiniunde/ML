# %%
import pandas as pd
import math
from collections import Counter

# %%
# Load dataset
df = pd.read_csv("loan_approval_dataset.csv")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 433.7+ KB
# None

# %%
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#    loan_status
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected

# %%
import pandas as pd
import numpy as np
import math



# -------------------------------
# Step 1: Preprocess numeric columns into categories
# -------------------------------
def discretize(column, bins=3, labels=["Low", "Medium", "High"]):
    return pd.cut(column, bins=bins, labels=labels)

# Apply discretization to numeric features
df['income_annum'] = discretize(df['income_annum'])
df['loan_amount'] = discretize(df['loan_amount'])
df['loan_term'] = discretize(df['loan_term'])
df['cibil_score'] = discretize(df['cibil_score'])
df['residential_assets_value'] = discretize(df['residential_assets_value'])
df['commercial_assets_value'] = discretize(df['commercial_assets_value'])
df['luxury_assets_value'] = discretize(df['luxury_assets_value'])
df['bank_asset_value'] = discretize(df['bank_asset_value'])

# Drop loan_id (not useful for prediction)
df = df.drop(columns=['loan_id'])

# -------------------------------
# Step 2: Entropy Function
# -------------------------------
def entropy(values):
    classes, counts = np.unique(values, return_counts=True)
    probs = counts / counts.sum()
    return -np.sum(probs * np.log2(probs))

# -------------------------------
# Step 3: Information Gain
# -------------------------------
def info_gain(df, attribute, target="loan_status"):
    total_entropy = entropy(df[target])
    values, counts = np.unique(df[attribute], return_counts=True)

    weighted_entropy = 0
    for v, c in zip(values, counts):
        subset = df[df[attribute] == v][target]
        weighted_entropy += (c / len(df)) * entropy(subset)

    return total_entropy - weighted_entropy

# -------------------------------
# Step 4: Build Tree Recursively
# -------------------------------
def build_tree(df, target="loan_status", attributes=None):
    # Leaf condition 1: if all values same → return that value
    if len(np.unique(df[target])) == 1:
        return np.unique(df[target])[0]

    # Leaf condition 2: if no attributes left → return majority
    if attributes is None or len(attributes) == 0:
        return df[target].mode()[0]

    # Choose best attribute (highest Info Gain)
    gains = {attr: info_gain(df, attr, target) for attr in attributes}
    best_attr = max(gains, key=gains.get)

    # Build tree as dictionary
    tree = {best_attr: {}}
    for val in df[best_attr].unique():
        subset = df[df[best_attr] == val]
        if subset.empty:
            tree[best_attr][val] = df[target].mode()[0]
        else:
            new_attrs = [a for a in attributes if a != best_attr]
            tree[best_attr][val] = build_tree(subset, target, new_attrs)
    return tree

# -------------------------------
# Step 5: Print Tree (Yes/No style)
# -------------------------------
def print_tree(tree, indent=""):
    root = list(tree.keys())[0]
    for val, branch in tree[root].items():
        if isinstance(branch, dict):
            print(f"{indent}{root} == {val}?")
            print_tree(branch, indent + "  ")
        else:
            print(f"{indent}{root} == {val} -> {branch}")

# -------------------------------
# Run the Tree
# -------------------------------
attributes = [col for col in df.columns if col != "loan_status"]

decision_tree = build_tree(df, target="loan_status", attributes=attributes)
print("\nDecision Tree Structure:\n")
print_tree(decision_tree)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'income_annum'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 14
#      11     return pd.cut(column, bins=bins, labels=labels)
#      13 # Apply discretization to numeric features
# ---> 14 df['income_annum'] = discretize(df['income_annum'])
#      15 df['loan_amount'] = discretize(df['loan_amount'])
#      16 df['loan_term'] = discretize(df['loan_term'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'income_annum'

# %%
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#    loan_status
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected

# %%
# -----------------------------
# Step 1: Entropy function
# -----------------------------
def entropy_of_attribute(data):
    counts = Counter(data)
    total = len(data)
    entropy = 0.0
    for label in counts:
        p = counts[label] / total
        entropy -= p * math.log2(p)
    return entropy

# %%
# -----------------------------
# Step 2: Information Gain
# -----------------------------
def information_gain(df, attribute, target="Loan_Status"):
    # Entropy before split
    total_entropy = entropy_of_attribute(df[target])

    # Weighted entropy after split
    values = df[attribute].unique()
    weighted_entropy = 0.0
    for val in values:
        subset = df[df[attribute] == val][target]
        weight = len(subset) / len(df)
        weighted_entropy += weight * entropy_of_attribute(subset)

    # Info Gain
    return total_entropy - weighted_entropy

# %%
# -----------------------------
# Step 3: Build Decision Tree (ID3)
# -----------------------------
def build_tree(df, target="Loan_Status", attributes=None):
    # If all labels are same → return leaf
    if len(df[target].unique()) == 1:
        return df[target].iloc[0]
    
    # If no attributes left → return majority class
    if attributes is None or len(attributes) == 0:
        return df[target].mode()[0]
    
    # Choose best attribute (highest gain)
    gains = {attr: information_gain(df, attr, target) for attr in attributes}
    best_attr = max(gains, key=gains.get)
    
    tree = {best_attr: {}}
    
    # Split and recurse
    for val in df[best_attr].unique():
        subset = df[df[best_attr] == val].drop(columns=[best_attr])
        new_attributes = [a for a in attributes if a != best_attr]
        tree[best_attr][val] = build_tree(subset, target, new_attributes)
    
    return tree

# %%
# -----------------------------
# Step 4: Pretty print tree
# -----------------------------
def print_tree(tree, indent=""):
    root = list(tree.keys())[0]
    branches = tree[root]
    for val, subtree in branches.items():
        if isinstance(subtree, dict):
            print(f"{indent}{root} = {val}:")
            print_tree(subtree, indent + "   ")
        else:
            print(f"{indent}{root} = {val} -> {subtree}")

# %%
print(df.columns)
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %%
# -----------------------------
# Step 5: Prediction function
# -----------------------------
def predict(tree, sample):
    root = list(tree.keys())[0]
    branches = tree[root]
    value = sample.get(root)
    
    if value not in branches:
        return "Unknown"
    
    subtree = branches[value]
    if isinstance(subtree, dict):
        return predict(subtree, sample)
    else:
        return subtree

# %%
# -----------------------------
# Run the Tree
# -----------------------------
attributes = [col for col in df.columns if col != ' loan_status']
#decision_tree = build_tree(df, target="loan_status", attributes=attributes)
decision_tree = build_tree(df, target=' loan_status', attributes=attributes)

print("\nDecision Tree Structure:\n")
print_tree(decision_tree)
# Out:
# Decision Tree Structure:
#
# loan_id = 1 ->  Approved
# loan_id = 2 ->  Rejected
# loan_id = 3 ->  Rejected
# loan_id = 4 ->  Rejected
# loan_id = 5 ->  Rejected
# loan_id = 6 ->  Rejected
# loan_id = 7 ->  Approved
# loan_id = 8 ->  Rejected
# loan_id = 9 ->  Approved
# loan_id = 10 ->  Rejected
# loan_id = 11 ->  Approved
# loan_id = 12 ->  Rejected
# loan_id = 13 ->  Rejected
# loan_id = 14 ->  Approved
# loan_id = 15 ->  Rejected
# loan_id = 16 ->  Approved
# loan_id = 17 ->  Approved
# loan_id = 18 ->  Approved
# loan_id = 19 ->  Approved
# loan_id = 20 ->  Approved
# loan_id = 21 ->  Rejected
# loan_id = 22 ->  Rejected
# loan_id = 23 ->  Rejected
# loan_id = 24 ->  Approved
# loan_id = 25 ->  Rejected
# loan_id = 26 ->  Rejected
# loan_id = 27 ->  Approved
# loan_id = 28 ->  Approved
# loan_id = 29 ->  Rejected
# loan_id = 30 ->  Approved
# loan_id = 31 ->  Rejected
# loan_id = 32 ->  Rejected
# loan_id = 33 ->  Rejected
# loan_id = 34 ->  Approved
# loan_id = 35 ->  Approved
# loan_id = 36 ->  Approved
# loan_id = 37 ->  Approved
# loan_id = 38 ->  Rejected
# loan_id = 39 ->  Approved
# loan_id = 40 ->  Rejected
# loan_id = 41 ->  Approved
# loan_id = 42 ->  Approved
# loan_id = 43 ->  Rejected
# loan_id = 44 ->  Rejected
# loan_id = 45 ->  Approved
# loan_id = 46 ->  Rejected
# loan_id = 47 ->  Approved
# loan_id = 48 ->  Approved
# loan_id = 49 ->  Approved
# loan_id = 50 ->  Approved
# loan_id = 51 ->  Rejected
# loan_id = 52 ->  Rejected
# loan_id = 53 ->  Approved
# loan_id = 54 ->  Approved
# loan_id = 55 ->  Approved
# loan_id = 56 ->  Approved
# loan_id = 57 ->  Rejected
# loan_id = 58 ->  Approved
# loan_id = 59 ->  Rejected
# loan_id = 60 ->  Approved
# loan_id = 61 ->  Rejected
# loan_id = 62 ->  Approved
# loan_id = 63 ->  Rejected
# loan_id = 64 ->  Approved
# loan_id = 65 ->  Approved
# loan_id = 66 ->  Rejected
# loan_id = 67 ->  Approved
# loan_id = 68 ->  Rejected
# loan_id = 69 ->  Approved
# loan_id = 70 ->  Rejected
# loan_id = 71 ->  Rejected
# loan_id = 72 ->  Approved
# loan_id = 73 ->  Rejected
# loan_id = 74 ->  Approved
# loan_id = 75 ->  Rejected
# loan_id = 76 ->  Approved
# loan_id = 77 ->  Approved
# loan_id = 78 ->  Approved
# loan_id = 79 ->  Approved
# loan_id = 80 ->  Approved
# loan_id = 81 ->  Rejected
# loan_id = 82 ->  Approved
# loan_id = 83 ->  Rejected
# loan_id = 84 ->  Approved
# loan_id = 85 ->  Approved
# loan_id = 86 ->  Rejected
# loan_id = 87 ->  Rejected
# loan_id = 88 ->  Rejected
# loan_id = 89 ->  Approved
# loan_id = 90 ->  Approved
# loan_id = 91 ->  Rejected
# loan_id = 92 ->  Rejected
# loan_id = 93 ->  Approved
# loan_id = 94 ->  Rejected
# loan_id = 95 ->  Rejected
# loan_id = 96 ->  Approved
# loan_id = 97 ->  Rejected
# loan_id = 98 ->  Approved
# loan_id = 99 ->  Approved
# loan_id = 100 ->  Rejected
# loan_id = 101 ->  Rejected
# loan_id = 102 ->  Approved
# loan_id = 103 ->  Approved
# loan_id = 104 ->  Approved
# loan_id = 105 ->  Rejected
# loan_id = 106 ->  Approved
# loan_id = 107 ->  Approved
# loan_id = 108 ->  Approved
# loan_id = 109 ->  Approved
# loan_id = 110 ->  Rejected
# loan_id = 111 ->  Approved
# loan_id = 112 ->  Rejected
# loan_id = 113 ->  Rejected
# loan_id = 114 ->  Approved
# loan_id = 115 ->  Rejected
# loan_id = 116 ->  Approved
# loan_id = 117 ->  Rejected
# loan_id = 118 ->  Approved
# loan_id = 119 ->  Rejected
# loan_id = 120 ->  Approved
# loan_id = 121 ->  Rejected
# loan_id = 122 ->  Rejected
# loan_id = 123 ->  Approved
# loan_id = 124 ->  Approved
# loan_id = 125 ->  Approved
# loan_id = 126 ->  Approved
# loan_id = 127 ->  Approved
# loan_id = 128 ->  Rejected
# loan_id = 129 ->  Rejected
# loan_id = 130 ->  Approved
# loan_id = 131 ->  Approved
# loan_id = 132 ->  Rejected
# loan_id = 133 ->  Rejected
# loan_id = 134 ->  Rejected
# loan_id = 135 ->  Approved
# loan_id = 136 ->  Rejected
# loan_id = 137 ->  Approved
# loan_id = 138 ->  Rejected
# loan_id = 139 ->  Approved
# loan_id = 140 ->  Rejected
# loan_id = 141 ->  Approved
# loan_id = 142 ->  Approved
# loan_id = 143 ->  Approved
# loan_id = 144 ->  Rejected
# loan_id = 145 ->  Approved
# loan_id = 146 ->  Rejected
# loan_id = 147 ->  Approved
# loan_id = 148 ->  Approved
# loan_id = 149 ->  Approved
# loan_id = 150 ->  Rejected
# loan_id = 151 ->  Rejected
# loan_id = 152 ->  Approved
# loan_id = 153 ->  Approved
# loan_id = 154 ->  Rejected
# loan_id = 155 ->  Rejected
# loan_id = 156 ->  Approved
# loan_id = 157 ->  Approved
# loan_id = 158 ->  Rejected
# loan_id = 159 ->  Approved
# loan_id = 160 ->  Rejected
# loan_id = 161 ->  Approved
# loan_id = 162 ->  Approved
# loan_id = 163 ->  Rejected
# loan_id = 164 ->  Approved
# loan_id = 165 ->  Approved
# loan_id = 166 ->  Approved
# loan_id = 167 ->  Approved
# loan_id = 168 ->  Rejected
# loan_id = 169 ->  Rejected
# loan_id = 170 ->  Approved
# loan_id = 171 ->  Approved
# loan_id = 172 ->  Approved
# loan_id = 173 ->  Approved
# loan_id = 174 ->  Rejected
# loan_id = 175 ->  Rejected
# loan_id = 176 ->  Approved
# loan_id = 177 ->  Approved
# loan_id = 178 ->  Rejected
# loan_id = 179 ->  Approved
# loan_id = 180 ->  Rejected
# loan_id = 181 ->  Approved
# loan_id = 182 ->  Approved
# loan_id = 183 ->  Approved
# loan_id = 184 ->  Approved
# loan_id = 185 ->  Approved
# loan_id = 186 ->  Approved
# loan_id = 187 ->  Approved
# loan_id = 188 ->  Approved
# loan_id = 189 ->  Approved
# loan_id = 190 ->  Rejected
# loan_id = 191 ->  Rejected
# loan_id = 192 ->  Approved
# loan_id = 193 ->  Approved
# loan_id = 194 ->  Approved
# loan_id = 195 ->  Approved
# loan_id = 196 ->  Rejected
# loan_id = 197 ->  Approved
# loan_id = 198 ->  Approved
# loan_id = 199 ->  Rejected
# loan_id = 200 ->  Rejected
# loan_id = 201 ->  Rejected
# loan_id = 202 ->  Rejected
# loan_id = 203 ->  Approved
# loan_id = 204 ->  Rejected
# loan_id = 205 ->  Approved
# loan_id = 206 ->  Approved
# loan_id = 207 ->  Approved
# loan_id = 208 ->  Approved
# loan_id = 209 ->  Rejected
# loan_id = 210 ->  Approved
# loan_id = 211 ->  Approved
# loan_id = 212 ->  Rejected
# loan_id = 213 ->  Rejected
# loan_id = 214 ->  Approved
# loan_id = 215 ->  Approved
# loan_id = 216 ->  Approved
# loan_id = 217 ->  Approved
# loan_id = 218 ->  Approved
# loan_id = 219 ->  Approved
# loan_id = 220 ->  Rejected
# loan_id = 221 ->  Approved
# loan_id = 222 ->  Approved
# loan_id = 223 ->  Rejected
# loan_id = 224 ->  Rejected
# loan_id = 225 ->  Approved
# loan_id = 226 ->  Rejected
# loan_id = 227 ->  Approved
# loan_id = 228 ->  Approved
# loan_id = 229 ->  Approved
# loan_id = 230 ->  Rejected
# loan_id = 231 ->  Approved
# loan_id = 232 ->  Approved
# loan_id = 233 ->  Approved
# loan_id = 234 ->  Rejected
# loan_id = 235 ->  Approved
# loan_id = 236 ->  Approved
# loan_id = 237 ->  Rejected
# loan_id = 238 ->  Approved
# loan_id = 239 ->  Approved
# loan_id = 240 ->  Rejected
# loan_id = 241 ->  Approved
# loan_id = 242 ->  Rejected
# loan_id = 243 ->  Approved
# loan_id = 244 ->  Approved
# loan_id = 245 ->  Approved
# loan_id = 246 ->  Approved
# loan_id = 247 ->  Approved
# loan_id = 248 ->  Rejected
# loan_id = 249 ->  Rejected
# loan_id = 250 ->  Approved
# loan_id = 251 ->  Rejected
# loan_id = 252 ->  Approved
# loan_id = 253 ->  Approved
# loan_id = 254 ->  Approved
# loan_id = 255 ->  Rejected
# loan_id = 256 ->  Rejected
# loan_id = 257 ->  Approved
# loan_id = 258 ->  Rejected
# loan_id = 259 ->  Approved
# loan_id = 260 ->  Approved
# loan_id = 261 ->  Approved
# loan_id = 262 ->  Approved
# loan_id = 263 ->  Rejected
# loan_id = 264 ->  Rejected
# loan_id = 265 ->  Approved
# loan_id = 266 ->  Approved
# loan_id = 267 ->  Approved
# loan_id = 268 ->  Approved
# loan_id = 269 ->  Approved
# loan_id = 270 ->  Approved
# loan_id = 271 ->  Rejected
# loan_id = 272 ->  Approved
# loan_id = 273 ->  Rejected
# loan_id = 274 ->  Rejected
# loan_id = 275 ->  Approved
# loan_id = 276 ->  Approved
# loan_id = 277 ->  Approved
# loan_id = 278 ->  Approved
# loan_id = 279 ->  Approved
# loan_id = 280 ->  Rejected
# loan_id = 281 ->  Approved
# loan_id = 282 ->  Rejected
# loan_id = 283 ->  Rejected
# loan_id = 284 ->  Rejected
# loan_id = 285 ->  Rejected
# loan_id = 286 ->  Rejected
# loan_id = 287 ->  Approved
# loan_id = 288 ->  Rejected
# loan_id = 289 ->  Approved
# loan_id = 290 ->  Rejected
# loan_id = 291 ->  Rejected
# loan_id = 292 ->  Rejected
# loan_id = 293 ->  Rejected
# loan_id = 294 ->  Rejected
# loan_id = 295 ->  Rejected
# loan_id = 296 ->  Rejected
# loan_id = 297 ->  Rejected
# loan_id = 298 ->  Rejected
# loan_id = 299 ->  Approved
# loan_id = 300 ->  Approved
# loan_id = 301 ->  Approved
# loan_id = 302 ->  Rejected
# loan_id = 303 ->  Approved
# loan_id = 304 ->  Approved
# loan_id = 305 ->  Approved
# loan_id = 306 ->  Approved
# loan_id = 307 ->  Approved
# loan_id = 308 ->  Rejected
# loan_id = 309 ->  Rejected
# loan_id = 310 ->  Rejected
# loan_id = 311 ->  Approved
# loan_id = 312 ->  Rejected
# loan_id = 313 ->  Approved
# loan_id = 314 ->  Approved
# loan_id = 315 ->  Approved
# loan_id = 316 ->  Approved
# loan_id = 317 ->  Approved
# loan_id = 318 ->  Approved
# loan_id = 319 ->  Approved
# loan_id = 320 ->  Rejected
# loan_id = 321 ->  Approved
# loan_id = 322 ->  Approved
# loan_id = 323 ->  Approved
# loan_id = 324 ->  Approved
# loan_id = 325 ->  Approved
# loan_id = 326 ->  Approved
# loan_id = 327 ->  Rejected
# loan_id = 328 ->  Rejected
# loan_id = 329 ->  Approved
# loan_id = 330 ->  Rejected
# loan_id = 331 ->  Rejected
# loan_id = 332 ->  Rejected
# loan_id = 333 ->  Approved
# loan_id = 334 ->  Rejected
# loan_id = 335 ->  Rejected
# loan_id = 336 ->  Approved
# loan_id = 337 ->  Approved
# loan_id = 338 ->  Rejected
# loan_id = 339 ->  Approved
# loan_id = 340 ->  Approved
# loan_id = 341 ->  Rejected
# loan_id = 342 ->  Rejected
# loan_id = 343 ->  Approved
# loan_id = 344 ->  Rejected
# loan_id = 345 ->  Approved
# loan_id = 346 ->  Rejected
# loan_id = 347 ->  Rejected
# loan_id = 348 ->  Approved
# loan_id = 349 ->  Rejected
# loan_id = 350 ->  Approved
# loan_id = 351 ->  Rejected
# loan_id = 352 ->  Approved
# loan_id = 353 ->  Approved
# loan_id = 354 ->  Approved
# loan_id = 355 ->  Rejected
# loan_id = 356 ->  Approved
# loan_id = 357 ->  Approved
# loan_id = 358 ->  Approved
# loan_id = 359 ->  Rejected
# loan_id = 360 ->  Approved
# loan_id = 361 ->  Approved
# loan_id = 362 ->  Approved
# loan_id = 363 ->  Rejected
# loan_id = 364 ->  Approved
# loan_id = 365 ->  Rejected
# loan_id = 366 ->  Approved
# loan_id = 367 ->  Approved
# loan_id = 368 ->  Rejected
# loan_id = 369 ->  Approved
# loan_id = 370 ->  Approved
# loan_id = 371 ->  Approved
# loan_id = 372 ->  Approved
# loan_id = 373 ->  Approved
# loan_id = 374 ->  Approved
# loan_id = 375 ->  Approved
# loan_id = 376 ->  Approved
# loan_id = 377 ->  Approved
# loan_id = 378 ->  Rejected
# loan_id = 379 ->  Rejected
# loan_id = 380 ->  Approved
# loan_id = 381 ->  Approved
# loan_id = 382 ->  Approved
# loan_id = 383 ->  Approved
# loan_id = 384 ->  Approved
# loan_id = 385 ->  Approved
# loan_id = 386 ->  Approved
# loan_id = 387 ->  Rejected
# loan_id = 388 ->  Rejected
# loan_id = 389 ->  Rejected
# loan_id = 390 ->  Approved
# loan_id = 391 ->  Approved
# loan_id = 392 ->  Approved
# loan_id = 393 ->  Approved
# loan_id = 394 ->  Approved
# loan_id = 395 ->  Approved
# loan_id = 396 ->  Rejected
# loan_id = 397 ->  Approved
# loan_id = 398 ->  Approved
# loan_id = 399 ->  Approved
# loan_id = 400 ->  Approved
# loan_id = 401 ->  Rejected
# loan_id = 402 ->  Rejected
# loan_id = 403 ->  Approved
# loan_id = 404 ->  Approved
# loan_id = 405 ->  Rejected
# loan_id = 406 ->  Approved
# loan_id = 407 ->  Rejected
# loan_id = 408 ->  Approved
# loan_id = 409 ->  Rejected
# loan_id = 410 ->  Approved
# loan_id = 411 ->  Rejected
# loan_id = 412 ->  Approved
# loan_id = 413 ->  Approved
# loan_id = 414 ->  Approved
# loan_id = 415 ->  Approved
# loan_id = 416 ->  Rejected
# loan_id = 417 ->  Rejected
# loan_id = 418 ->  Rejected
# loan_id = 419 ->  Approved
# loan_id = 420 ->  Approved
# loan_id = 421 ->  Approved
# loan_id = 422 ->  Approved
# loan_id = 423 ->  Rejected
# loan_id = 424 ->  Approved
# loan_id = 425 ->  Approved
# loan_id = 426 ->  Rejected
# loan_id = 427 ->  Rejected
# loan_id = 428 ->  Approved
# loan_id = 429 ->  Approved
# loan_id = 430 ->  Approved
# loan_id = 431 ->  Rejected
# loan_id = 432 ->  Approved
# loan_id = 433 ->  Approved
# loan_id = 434 ->  Approved
# loan_id = 435 ->  Approved
# loan_id = 436 ->  Approved
# loan_id = 437 ->  Approved
# loan_id = 438 ->  Rejected
# loan_id = 439 ->  Approved
# loan_id = 440 ->  Approved
# loan_id = 441 ->  Approved
# loan_id = 442 ->  Approved
# loan_id = 443 ->  Approved
# loan_id = 444 ->  Approved
# loan_id = 445 ->  Rejected
# loan_id = 446 ->  Approved
# loan_id = 447 ->  Approved
# loan_id = 448 ->  Rejected
# loan_id = 449 ->  Approved
# loan_id = 450 ->  Rejected
# loan_id = 451 ->  Approved
# loan_id = 452 ->  Approved
# loan_id = 453 ->  Rejected
# loan_id = 454 ->  Approved
# loan_id = 455 ->  Approved
# loan_id = 456 ->  Approved
# loan_id = 457 ->  Approved
# loan_id = 458 ->  Approved
# loan_id = 459 ->  Approved
# loan_id = 460 ->  Rejected
# loan_id = 461 ->  Rejected
# loan_id = 462 ->  Approved
# loan_id = 463 ->  Approved
# loan_id = 464 ->  Approved
# loan_id = 465 ->  Rejected
# loan_id = 466 ->  Approved
# loan_id = 467 ->  Rejected
# loan_id = 468 ->  Approved
# loan_id = 469 ->  Rejected
# loan_id = 470 ->  Rejected
# loan_id = 471 ->  Rejected
# loan_id = 472 ->  Approved
# loan_id = 473 ->  Approved
# loan_id = 474 ->  Rejected
# loan_id = 475 ->  Approved
# loan_id = 476 ->  Approved
# loan_id = 477 ->  Rejected
# loan_id = 478 ->  Rejected
# loan_id = 479 ->  Approved
# loan_id = 480 ->  Approved
# loan_id = 481 ->  Rejected
# loan_id = 482 ->  Approved
# loan_id = 483 ->  Rejected
# loan_id = 484 ->  Rejected
# loan_id = 485 ->  Approved
# loan_id = 486 ->  Approved
# loan_id = 487 ->  Approved
# loan_id = 488 ->  Approved
# loan_id = 489 ->  Rejected
# loan_id = 490 ->  Rejected
# loan_id = 491 ->  Approved
# loan_id = 492 ->  Approved
# loan_id = 493 ->  Approved
# loan_id = 494 ->  Rejected
# loan_id = 495 ->  Rejected
# loan_id = 496 ->  Approved
# loan_id = 497 ->  Approved
# loan_id = 498 ->  Rejected
# loan_id = 499 ->  Rejected
# loan_id = 500 ->  Approved
# loan_id = 501 ->  Approved
# loan_id = 502 ->  Rejected
# loan_id = 503 ->  Approved
# loan_id = 504 ->  Approved
# loan_id = 505 ->  Approved
# loan_id = 506 ->  Approved
# loan_id = 507 ->  Rejected
# loan_id = 508 ->  Approved
# loan_id = 509 ->  Rejected
# loan_id = 510 ->  Approved
# loan_id = 511 ->  Rejected
# loan_id = 512 ->  Approved
# loan_id = 513 ->  Rejected
# loan_id = 514 ->  Approved
# loan_id = 515 ->  Rejected
# loan_id = 516 ->  Rejected
# loan_id = 517 ->  Approved
# loan_id = 518 ->  Rejected
# loan_id = 519 ->  Approved
# loan_id = 520 ->  Rejected
# loan_id = 521 ->  Approved
# loan_id = 522 ->  Approved
# loan_id = 523 ->  Rejected
# loan_id = 524 ->  Rejected
# loan_id = 525 ->  Approved
# loan_id = 526 ->  Approved
# loan_id = 527 ->  Approved
# loan_id = 528 ->  Approved
# loan_id = 529 ->  Approved
# loan_id = 530 ->  Approved
# loan_id = 531 ->  Approved
# loan_id = 532 ->  Approved
# loan_id = 533 ->  Rejected
# loan_id = 534 ->  Approved
# loan_id = 535 ->  Rejected
# loan_id = 536 ->  Rejected
# loan_id = 537 ->  Approved
# loan_id = 538 ->  Rejected
# loan_id = 539 ->  Approved
# loan_id = 540 ->  Approved
# loan_id = 541 ->  Approved
# loan_id = 542 ->  Rejected
# loan_id = 543 ->  Rejected
# loan_id = 544 ->  Approved
# loan_id = 545 ->  Approved
# loan_id = 546 ->  Approved
# loan_id = 547 ->  Approved
# loan_id = 548 ->  Rejected
# loan_id = 549 ->  Approved
# loan_id = 550 ->  Approved
# loan_id = 551 ->  Rejected
# loan_id = 552 ->  Approved
# loan_id = 553 ->  Approved
# loan_id = 554 ->  Approved
# loan_id = 555 ->  Rejected
# loan_id = 556 ->  Approved
# loan_id = 557 ->  Rejected
# loan_id = 558 ->  Approved
# loan_id = 559 ->  Rejected
# loan_id = 560 ->  Rejected
# loan_id = 561 ->  Approved
# loan_id = 562 ->  Approved
# loan_id = 563 ->  Rejected
# loan_id = 564 ->  Approved
# loan_id = 565 ->  Approved
# loan_id = 566 ->  Approved
# loan_id = 567 ->  Approved
# loan_id = 568 ->  Rejected
# loan_id = 569 ->  Approved
# loan_id = 570 ->  Approved
# loan_id = 571 ->  Rejected
# loan_id = 572 ->  Approved
# loan_id = 573 ->  Approved
# loan_id = 574 ->  Approved
# loan_id = 575 ->  Rejected
# loan_id = 576 ->  Approved
# loan_id = 577 ->  Approved
# loan_id = 578 ->  Approved
# loan_id = 579 ->  Approved
# loan_id = 580 ->  Rejected
# loan_id = 581 ->  Rejected
# loan_id = 582 ->  Approved
# loan_id = 583 ->  Rejected
# loan_id = 584 ->  Approved
# loan_id = 585 ->  Rejected
# loan_id = 586 ->  Approved
# loan_id = 587 ->  Approved
# loan_id = 588 ->  Rejected
# loan_id = 589 ->  Approved
# loan_id = 590 ->  Approved
# loan_id = 591 ->  Rejected
# loan_id = 592 ->  Rejected
# loan_id = 593 ->  Rejected
# loan_id = 594 ->  Approved
# loan_id = 595 ->  Rejected
# loan_id = 596 ->  Approved
# loan_id = 597 ->  Approved
# loan_id = 598 ->  Rejected
# loan_id = 599 ->  Approved
# loan_id = 600 ->  Approved
# loan_id = 601 ->  Rejected
# loan_id = 602 ->  Approved
# loan_id = 603 ->  Approved
# loan_id = 604 ->  Rejected
# loan_id = 605 ->  Approved
# loan_id = 606 ->  Approved
# loan_id = 607 ->  Approved
# loan_id = 608 ->  Rejected
# loan_id = 609 ->  Approved
# loan_id = 610 ->  Approved
# loan_id = 611 ->  Rejected
# loan_id = 612 ->  Approved
# loan_id = 613 ->  Rejected
# loan_id = 614 ->  Approved
# loan_id = 615 ->  Approved
# loan_id = 616 ->  Rejected
# loan_id = 617 ->  Approved
# loan_id = 618 ->  Rejected
# loan_id = 619 ->  Approved
# loan_id = 620 ->  Approved
# loan_id = 621 ->  Approved
# loan_id = 622 ->  Approved
# loan_id = 623 ->  Approved
# loan_id = 624 ->  Approved
# loan_id = 625 ->  Approved
# loan_id = 626 ->  Approved
# loan_id = 627 ->  Approved
# loan_id = 628 ->  Approved
# loan_id = 629 ->  Rejected
# loan_id = 630 ->  Rejected
# loan_id = 631 ->  Approved
# loan_id = 632 ->  Approved
# loan_id = 633 ->  Rejected
# loan_id = 634 ->  Approved
# loan_id = 635 ->  Rejected
# loan_id = 636 ->  Approved
# loan_id = 637 ->  Approved
# loan_id = 638 ->  Approved
# loan_id = 639 ->  Approved
# loan_id = 640 ->  Approved
# loan_id = 641 ->  Approved
# loan_id = 642 ->  Approved
# loan_id = 643 ->  Approved
# loan_id = 644 ->  Approved
# loan_id = 645 ->  Approved
# loan_id = 646 ->  Rejected
# loan_id = 647 ->  Approved
# loan_id = 648 ->  Approved
# loan_id = 649 ->  Approved
# loan_id = 650 ->  Rejected
# loan_id = 651 ->  Approved
# loan_id = 652 ->  Rejected
# loan_id = 653 ->  Approved
# loan_id = 654 ->  Approved
# loan_id = 655 ->  Approved
# loan_id = 656 ->  Rejected
# loan_id = 657 ->  Rejected
# loan_id = 658 ->  Rejected
# loan_id = 659 ->  Rejected
# loan_id = 660 ->  Approved
# loan_id = 661 ->  Approved
# loan_id = 662 ->  Approved
# loan_id = 663 ->  Rejected
# loan_id = 664 ->  Rejected
# loan_id = 665 ->  Rejected
# loan_id = 666 ->  Rejected
# loan_id = 667 ->  Rejected
# loan_id = 668 ->  Approved
# loan_id = 669 ->  Rejected
# loan_id = 670 ->  Rejected
# loan_id = 671 ->  Rejected
# loan_id = 672 ->  Approved
# loan_id = 673 ->  Approved
# loan_id = 674 ->  Rejected
# loan_id = 675 ->  Rejected
# loan_id = 676 ->  Approved
# loan_id = 677 ->  Approved
# loan_id = 678 ->  Approved
# loan_id = 679 ->  Approved
# loan_id = 680 ->  Approved
# loan_id = 681 ->  Approved
# loan_id = 682 ->  Rejected
# loan_id = 683 ->  Approved
# loan_id = 684 ->  Rejected
# loan_id = 685 ->  Approved
# loan_id = 686 ->  Approved
# loan_id = 687 ->  Rejected
# loan_id = 688 ->  Approved
# loan_id = 689 ->  Approved
# loan_id = 690 ->  Rejected
# loan_id = 691 ->  Rejected
# loan_id = 692 ->  Approved
# loan_id = 693 ->  Approved
# loan_id = 694 ->  Approved
# loan_id = 695 ->  Approved
# loan_id = 696 ->  Approved
# loan_id = 697 ->  Approved
# loan_id = 698 ->  Approved
# loan_id = 699 ->  Rejected
# loan_id = 700 ->  Approved
# loan_id = 701 ->  Approved
# loan_id = 702 ->  Rejected
# loan_id = 703 ->  Approved
# loan_id = 704 ->  Rejected
# loan_id = 705 ->  Approved
# loan_id = 706 ->  Rejected
# loan_id = 707 ->  Approved
# loan_id = 708 ->  Rejected
# loan_id = 709 ->  Rejected
# loan_id = 710 ->  Approved
# loan_id = 711 ->  Rejected
# loan_id = 712 ->  Rejected
# loan_id = 713 ->  Approved
# loan_id = 714 ->  Approved
# loan_id = 715 ->  Approved
# loan_id = 716 ->  Approved
# loan_id = 717 ->  Approved
# loan_id = 718 ->  Rejected
# loan_id = 719 ->  Approved
# loan_id = 720 ->  Rejected
# loan_id = 721 ->  Approved
# loan_id = 722 ->  Approved
# loan_id = 723 ->  Rejected
# loan_id = 724 ->  Rejected
# loan_id = 725 ->  Rejected
# loan_id = 726 ->  Approved
# loan_id = 727 ->  Rejected
# loan_id = 728 ->  Approved
# loan_id = 729 ->  Rejected
# loan_id = 730 ->  Approved
# loan_id = 731 ->  Rejected
# loan_id = 732 ->  Approved
# loan_id = 733 ->  Rejected
# loan_id = 734 ->  Approved
# loan_id = 735 ->  Rejected
# loan_id = 736 ->  Approved
# loan_id = 737 ->  Approved
# loan_id = 738 ->  Rejected
# loan_id = 739 ->  Approved
# loan_id = 740 ->  Rejected
# loan_id = 741 ->  Rejected
# loan_id = 742 ->  Approved
# loan_id = 743 ->  Rejected
# loan_id = 744 ->  Rejected
# loan_id = 745 ->  Rejected
# loan_id = 746 ->  Approved
# loan_id = 747 ->  Approved
# loan_id = 748 ->  Rejected
# loan_id = 749 ->  Approved
# loan_id = 750 ->  Approved
# loan_id = 751 ->  Approved
# loan_id = 752 ->  Rejected
# loan_id = 753 ->  Approved
# loan_id = 754 ->  Approved
# loan_id = 755 ->  Rejected
# loan_id = 756 ->  Approved
# loan_id = 757 ->  Rejected
# loan_id = 758 ->  Rejected
# loan_id = 759 ->  Rejected
# loan_id = 760 ->  Rejected
# loan_id = 761 ->  Approved
# loan_id = 762 ->  Approved
# loan_id = 763 ->  Rejected
# loan_id = 764 ->  Approved
# loan_id = 765 ->  Rejected
# loan_id = 766 ->  Approved
# loan_id = 767 ->  Approved
# loan_id = 768 ->  Approved
# loan_id = 769 ->  Approved
# loan_id = 770 ->  Approved
# loan_id = 771 ->  Approved
# loan_id = 772 ->  Rejected
# loan_id = 773 ->  Approved
# loan_id = 774 ->  Rejected
# loan_id = 775 ->  Approved
# loan_id = 776 ->  Approved
# loan_id = 777 ->  Approved
# loan_id = 778 ->  Rejected
# loan_id = 779 ->  Approved
# loan_id = 780 ->  Approved
# loan_id = 781 ->  Approved
# loan_id = 782 ->  Approved
# loan_id = 783 ->  Approved
# loan_id = 784 ->  Approved
# loan_id = 785 ->  Approved
# loan_id = 786 ->  Approved
# loan_id = 787 ->  Approved
# loan_id = 788 ->  Approved
# loan_id = 789 ->  Approved
# loan_id = 790 ->  Rejected
# loan_id = 791 ->  Approved
# loan_id = 792 ->  Rejected
# loan_id = 793 ->  Rejected
# loan_id = 794 ->  Rejected
# loan_id = 795 ->  Approved
# loan_id = 796 ->  Rejected
# loan_id = 797 ->  Rejected
# loan_id = 798 ->  Rejected
# loan_id = 799 ->  Approved
# loan_id = 800 ->  Rejected
# loan_id = 801 ->  Approved
# loan_id = 802 ->  Rejected
# loan_id = 803 ->  Approved
# loan_id = 804 ->  Rejected
# loan_id = 805 ->  Approved
# loan_id = 806 ->  Approved
# loan_id = 807 ->  Approved
# loan_id = 808 ->  Approved
# loan_id = 809 ->  Rejected
# loan_id = 810 ->  Approved
# loan_id = 811 ->  Approved
# loan_id = 812 ->  Approved
# loan_id = 813 ->  Approved
# loan_id = 814 ->  Rejected
# loan_id = 815 ->  Approved
# loan_id = 816 ->  Rejected
# loan_id = 817 ->  Approved
# loan_id = 818 ->  Approved
# loan_id = 819 ->  Approved
# loan_id = 820 ->  Approved
# loan_id = 821 ->  Approved
# loan_id = 822 ->  Approved
# loan_id = 823 ->  Rejected
# loan_id = 824 ->  Approved
# loan_id = 825 ->  Approved
# loan_id = 826 ->  Approved
# loan_id = 827 ->  Approved
# loan_id = 828 ->  Approved
# loan_id = 829 ->  Rejected
# loan_id = 830 ->  Approved
# loan_id = 831 ->  Approved
# loan_id = 832 ->  Approved
# loan_id = 833 ->  Approved
# loan_id = 834 ->  Approved
# loan_id = 835 ->  Approved
# loan_id = 836 ->  Approved
# loan_id = 837 ->  Rejected
# loan_id = 838 ->  Rejected
# loan_id = 839 ->  Approved
# loan_id = 840 ->  Approved
# loan_id = 841 ->  Rejected
# loan_id = 842 ->  Approved
# loan_id = 843 ->  Approved
# loan_id = 844 ->  Rejected
# loan_id = 845 ->  Rejected
# loan_id = 846 ->  Approved
# loan_id = 847 ->  Approved
# loan_id = 848 ->  Rejected
# loan_id = 849 ->  Rejected
# loan_id = 850 ->  Rejected
# loan_id = 851 ->  Approved
# loan_id = 852 ->  Approved
# loan_id = 853 ->  Rejected
# loan_id = 854 ->  Rejected
# loan_id = 855 ->  Rejected
# loan_id = 856 ->  Rejected
# loan_id = 857 ->  Rejected
# loan_id = 858 ->  Approved
# loan_id = 859 ->  Rejected
# loan_id = 860 ->  Rejected
# loan_id = 861 ->  Approved
# loan_id = 862 ->  Approved
# loan_id = 863 ->  Approved
# loan_id = 864 ->  Approved
# loan_id = 865 ->  Approved
# loan_id = 866 ->  Rejected
# loan_id = 867 ->  Approved
# loan_id = 868 ->  Rejected
# loan_id = 869 ->  Rejected
# loan_id = 870 ->  Approved
# loan_id = 871 ->  Approved
# loan_id = 872 ->  Approved
# loan_id = 873 ->  Approved
# loan_id = 874 ->  Approved
# loan_id = 875 ->  Approved
# loan_id = 876 ->  Rejected
# loan_id = 877 ->  Rejected
# loan_id = 878 ->  Approved
# loan_id = 879 ->  Rejected
# loan_id = 880 ->  Rejected
# loan_id = 881 ->  Rejected
# loan_id = 882 ->  Rejected
# loan_id = 883 ->  Rejected
# loan_id = 884 ->  Approved
# loan_id = 885 ->  Approved
# loan_id = 886 ->  Approved
# loan_id = 887 ->  Approved
# loan_id = 888 ->  Approved
# loan_id = 889 ->  Approved
# loan_id = 890 ->  Rejected
# loan_id = 891 ->  Rejected
# loan_id = 892 ->  Rejected
# loan_id = 893 ->  Rejected
# loan_id = 894 ->  Approved
# loan_id = 895 ->  Approved
# loan_id = 896 ->  Rejected
# loan_id = 897 ->  Approved
# loan_id = 898 ->  Approved
# loan_id = 899 ->  Rejected
# loan_id = 900 ->  Approved
# loan_id = 901 ->  Approved
# loan_id = 902 ->  Rejected
# loan_id = 903 ->  Approved
# loan_id = 904 ->  Approved
# loan_id = 905 ->  Approved
# loan_id = 906 ->  Rejected
# loan_id = 907 ->  Approved
# loan_id = 908 ->  Rejected
# loan_id = 909 ->  Rejected
# loan_id = 910 ->  Rejected
# loan_id = 911 ->  Approved
# loan_id = 912 ->  Rejected
# loan_id = 913 ->  Approved
# loan_id = 914 ->  Approved
# loan_id = 915 ->  Approved
# loan_id = 916 ->  Approved
# loan_id = 917 ->  Approved
# loan_id = 918 ->  Rejected
# loan_id = 919 ->  Rejected
# loan_id = 920 ->  Approved
# loan_id = 921 ->  Approved
# loan_id = 922 ->  Rejected
# loan_id = 923 ->  Approved
# loan_id = 924 ->  Approved
# loan_id = 925 ->  Rejected
# loan_id = 926 ->  Rejected
# loan_id = 927 ->  Rejected
# loan_id = 928 ->  Approved
# loan_id = 929 ->  Rejected
# loan_id = 930 ->  Rejected
# loan_id = 931 ->  Rejected
# loan_id = 932 ->  Approved
# loan_id = 933 ->  Approved
# loan_id = 934 ->  Approved
# loan_id = 935 ->  Approved
# loan_id = 936 ->  Approved
# loan_id = 937 ->  Rejected
# loan_id = 938 ->  Approved
# loan_id = 939 ->  Rejected
# loan_id = 940 ->  Approved
# loan_id = 941 ->  Rejected
# loan_id = 942 ->  Approved
# loan_id = 943 ->  Rejected
# loan_id = 944 ->  Approved
# loan_id = 945 ->  Approved
# loan_id = 946 ->  Rejected
# loan_id = 947 ->  Approved
# loan_id = 948 ->  Rejected
# loan_id = 949 ->  Rejected
# loan_id = 950 ->  Rejected
# loan_id = 951 ->  Rejected
# loan_id = 952 ->  Approved
# loan_id = 953 ->  Approved
# loan_id = 954 ->  Approved
# loan_id = 955 ->  Approved
# loan_id = 956 ->  Approved
# loan_id = 957 ->  Rejected
# loan_id = 958 ->  Approved
# loan_id = 959 ->  Rejected
# loan_id = 960 ->  Approved
# loan_id = 961 ->  Rejected
# loan_id = 962 ->  Approved
# loan_id = 963 ->  Approved
# loan_id = 964 ->  Approved
# loan_id = 965 ->  Approved
# loan_id = 966 ->  Approved
# loan_id = 967 ->  Rejected
# loan_id = 968 ->  Approved
# loan_id = 969 ->  Approved
# loan_id = 970 ->  Rejected
# loan_id = 971 ->  Approved
# loan_id = 972 ->  Approved
# loan_id = 973 ->  Approved
# loan_id = 974 ->  Approved
# loan_id = 975 ->  Approved
# loan_id = 976 ->  Rejected
# loan_id = 977 ->  Rejected
# loan_id = 978 ->  Approved
# loan_id = 979 ->  Rejected
# loan_id = 980 ->  Approved
# loan_id = 981 ->  Approved
# loan_id = 982 ->  Rejected
# loan_id = 983 ->  Rejected
# loan_id = 984 ->  Approved
# loan_id = 985 ->  Approved
# loan_id = 986 ->  Rejected
# loan_id = 987 ->  Rejected
# loan_id = 988 ->  Approved
# loan_id = 989 ->  Approved
# loan_id = 990 ->  Approved
# loan_id = 991 ->  Approved
# loan_id = 992 ->  Approved
# loan_id = 993 ->  Approved
# loan_id = 994 ->  Approved
# loan_id = 995 ->  Approved
# loan_id = 996 ->  Approved
# loan_id = 997 ->  Rejected
# loan_id = 998 ->  Approved
# loan_id = 999 ->  Approved
# loan_id = 1000 ->  Approved
# loan_id = 1001 ->  Approved
# loan_id = 1002 ->  Approved
# loan_id = 1003 ->  Rejected
# loan_id = 1004 ->  Rejected
# loan_id = 1005 ->  Rejected
# loan_id = 1006 ->  Approved
# loan_id = 1007 ->  Approved
# loan_id = 1008 ->  Approved
# loan_id = 1009 ->  Approved
# loan_id = 1010 ->  Approved
# loan_id = 1011 ->  Rejected
# loan_id = 1012 ->  Rejected
# loan_id = 1013 ->  Rejected
# loan_id = 1014 ->  Approved
# loan_id = 1015 ->  Rejected
# loan_id = 1016 ->  Approved
# loan_id = 1017 ->  Approved
# loan_id = 1018 ->  Rejected
# loan_id = 1019 ->  Approved
# loan_id = 1020 ->  Approved
# loan_id = 1021 ->  Rejected
# loan_id = 1022 ->  Rejected
# loan_id = 1023 ->  Approved
# loan_id = 1024 ->  Approved
# loan_id = 1025 ->  Approved
# loan_id = 1026 ->  Approved
# loan_id = 1027 ->  Approved
# loan_id = 1028 ->  Approved
# loan_id = 1029 ->  Rejected
# loan_id = 1030 ->  Approved
# loan_id = 1031 ->  Rejected
# loan_id = 1032 ->  Approved
# loan_id = 1033 ->  Rejected
# loan_id = 1034 ->  Approved
# loan_id = 1035 ->  Approved
# loan_id = 1036 ->  Approved
# loan_id = 1037 ->  Approved
# loan_id = 1038 ->  Rejected
# loan_id = 1039 ->  Rejected
# loan_id = 1040 ->  Rejected
# loan_id = 1041 ->  Approved
# loan_id = 1042 ->  Approved
# loan_id = 1043 ->  Approved
# loan_id = 1044 ->  Approved
# loan_id = 1045 ->  Approved
# loan_id = 1046 ->  Approved
# loan_id = 1047 ->  Rejected
# loan_id = 1048 ->  Approved
# loan_id = 1049 ->  Approved
# loan_id = 1050 ->  Approved
# loan_id = 1051 ->  Rejected
# loan_id = 1052 ->  Approved
# loan_id = 1053 ->  Rejected
# loan_id = 1054 ->  Approved
# loan_id = 1055 ->  Rejected
# loan_id = 1056 ->  Rejected
# loan_id = 1057 ->  Rejected
# loan_id = 1058 ->  Rejected
# loan_id = 1059 ->  Rejected
# loan_id = 1060 ->  Rejected
# loan_id = 1061 ->  Approved
# loan_id = 1062 ->  Rejected
# loan_id = 1063 ->  Rejected
# loan_id = 1064 ->  Approved
# loan_id = 1065 ->  Approved
# loan_id = 1066 ->  Rejected
# loan_id = 1067 ->  Approved
# loan_id = 1068 ->  Approved
# loan_id = 1069 ->  Approved
# loan_id = 1070 ->  Approved
# loan_id = 1071 ->  Rejected
# loan_id = 1072 ->  Rejected
# loan_id = 1073 ->  Rejected
# loan_id = 1074 ->  Approved
# loan_id = 1075 ->  Approved
# loan_id = 1076 ->  Approved
# loan_id = 1077 ->  Approved
# loan_id = 1078 ->  Rejected
# loan_id = 1079 ->  Rejected
# loan_id = 1080 ->  Approved
# loan_id = 1081 ->  Rejected
# loan_id = 1082 ->  Approved
# loan_id = 1083 ->  Approved
# loan_id = 1084 ->  Rejected
# loan_id = 1085 ->  Approved
# loan_id = 1086 ->  Approved
# loan_id = 1087 ->  Approved
# loan_id = 1088 ->  Approved
# loan_id = 1089 ->  Approved
# loan_id = 1090 ->  Rejected
# loan_id = 1091 ->  Approved
# loan_id = 1092 ->  Approved
# loan_id = 1093 ->  Approved
# loan_id = 1094 ->  Rejected
# loan_id = 1095 ->  Rejected
# loan_id = 1096 ->  Rejected
# loan_id = 1097 ->  Rejected
# loan_id = 1098 ->  Approved
# loan_id = 1099 ->  Approved
# loan_id = 1100 ->  Approved
# loan_id = 1101 ->  Approved
# loan_id = 1102 ->  Approved
# loan_id = 1103 ->  Rejected
# loan_id = 1104 ->  Approved
# loan_id = 1105 ->  Approved
# loan_id = 1106 ->  Approved
# loan_id = 1107 ->  Approved
# loan_id = 1108 ->  Approved
# loan_id = 1109 ->  Rejected
# loan_id = 1110 ->  Approved
# loan_id = 1111 ->  Approved
# loan_id = 1112 ->  Approved
# loan_id = 1113 ->  Approved
# loan_id = 1114 ->  Rejected
# loan_id = 1115 ->  Rejected
# loan_id = 1116 ->  Approved
# loan_id = 1117 ->  Rejected
# loan_id = 1118 ->  Approved
# loan_id = 1119 ->  Approved
# loan_id = 1120 ->  Approved
# loan_id = 1121 ->  Rejected
# loan_id = 1122 ->  Approved
# loan_id = 1123 ->  Rejected
# loan_id = 1124 ->  Rejected
# loan_id = 1125 ->  Approved
# loan_id = 1126 ->  Approved
# loan_id = 1127 ->  Rejected
# loan_id = 1128 ->  Rejected
# loan_id = 1129 ->  Approved
# loan_id = 1130 ->  Approved
# loan_id = 1131 ->  Approved
# loan_id = 1132 ->  Approved
# loan_id = 1133 ->  Approved
# loan_id = 1134 ->  Approved
# loan_id = 1135 ->  Rejected
# loan_id = 1136 ->  Rejected
# loan_id = 1137 ->  Approved
# loan_id = 1138 ->  Rejected
# loan_id = 1139 ->  Rejected
# loan_id = 1140 ->  Approved
# loan_id = 1141 ->  Approved
# loan_id = 1142 ->  Rejected
# loan_id = 1143 ->  Rejected
# loan_id = 1144 ->  Approved
# loan_id = 1145 ->  Approved
# loan_id = 1146 ->  Approved
# loan_id = 1147 ->  Approved
# loan_id = 1148 ->  Rejected
# loan_id = 1149 ->  Approved
# loan_id = 1150 ->  Rejected
# loan_id = 1151 ->  Approved
# loan_id = 1152 ->  Rejected
# loan_id = 1153 ->  Rejected
# loan_id = 1154 ->  Approved
# loan_id = 1155 ->  Approved
# loan_id = 1156 ->  Rejected
# loan_id = 1157 ->  Rejected
# loan_id = 1158 ->  Approved
# loan_id = 1159 ->  Approved
# loan_id = 1160 ->  Approved
# loan_id = 1161 ->  Rejected
# loan_id = 1162 ->  Rejected
# loan_id = 1163 ->  Approved
# loan_id = 1164 ->  Approved
# loan_id = 1165 ->  Approved
# loan_id = 1166 ->  Approved
# loan_id = 1167 ->  Rejected
# loan_id = 1168 ->  Approved
# loan_id = 1169 ->  Rejected
# loan_id = 1170 ->  Rejected
# loan_id = 1171 ->  Approved
# loan_id = 1172 ->  Approved
# loan_id = 1173 ->  Approved
# loan_id = 1174 ->  Approved
# loan_id = 1175 ->  Rejected
# loan_id = 1176 ->  Rejected
# loan_id = 1177 ->  Approved
# loan_id = 1178 ->  Approved
# loan_id = 1179 ->  Approved
# loan_id = 1180 ->  Rejected
# loan_id = 1181 ->  Rejected
# loan_id = 1182 ->  Approved
# loan_id = 1183 ->  Approved
# loan_id = 1184 ->  Rejected
# loan_id = 1185 ->  Approved
# loan_id = 1186 ->  Approved
# loan_id = 1187 ->  Rejected
# loan_id = 1188 ->  Rejected
# loan_id = 1189 ->  Approved
# loan_id = 1190 ->  Approved
# loan_id = 1191 ->  Rejected
# loan_id = 1192 ->  Approved
# loan_id = 1193 ->  Approved
# loan_id = 1194 ->  Rejected
# loan_id = 1195 ->  Rejected
# loan_id = 1196 ->  Approved
# loan_id = 1197 ->  Approved
# loan_id = 1198 ->  Approved
# loan_id = 1199 ->  Rejected
# loan_id = 1200 ->  Rejected
# loan_id = 1201 ->  Approved
# loan_id = 1202 ->  Approved
# loan_id = 1203 ->  Rejected
# loan_id = 1204 ->  Approved
# loan_id = 1205 ->  Rejected
# loan_id = 1206 ->  Rejected
# loan_id = 1207 ->  Approved
# loan_id = 1208 ->  Approved
# loan_id = 1209 ->  Approved
# loan_id = 1210 ->  Approved
# loan_id = 1211 ->  Approved
# loan_id = 1212 ->  Rejected
# loan_id = 1213 ->  Approved
# loan_id = 1214 ->  Approved
# loan_id = 1215 ->  Approved
# loan_id = 1216 ->  Rejected
# loan_id = 1217 ->  Approved
# loan_id = 1218 ->  Rejected
# loan_id = 1219 ->  Approved
# loan_id = 1220 ->  Approved
# loan_id = 1221 ->  Approved
# loan_id = 1222 ->  Approved
# loan_id = 1223 ->  Rejected
# loan_id = 1224 ->  Approved
# loan_id = 1225 ->  Rejected
# loan_id = 1226 ->  Approved
# loan_id = 1227 ->  Rejected
# loan_id = 1228 ->  Rejected
# loan_id = 1229 ->  Approved
# loan_id = 1230 ->  Rejected
# loan_id = 1231 ->  Rejected
# loan_id = 1232 ->  Approved
# loan_id = 1233 ->  Approved
# loan_id = 1234 ->  Rejected
# loan_id = 1235 ->  Approved
# loan_id = 1236 ->  Approved
# loan_id = 1237 ->  Approved
# loan_id = 1238 ->  Approved
# loan_id = 1239 ->  Approved
# loan_id = 1240 ->  Approved
# loan_id = 1241 ->  Approved
# loan_id = 1242 ->  Approved
# loan_id = 1243 ->  Rejected
# loan_id = 1244 ->  Rejected
# loan_id = 1245 ->  Approved
# loan_id = 1246 ->  Approved
# loan_id = 1247 ->  Approved
# loan_id = 1248 ->  Approved
# loan_id = 1249 ->  Approved
# loan_id = 1250 ->  Rejected
# loan_id = 1251 ->  Approved
# loan_id = 1252 ->  Approved
# loan_id = 1253 ->  Approved
# loan_id = 1254 ->  Approved
# loan_id = 1255 ->  Approved
# loan_id = 1256 ->  Approved
# loan_id = 1257 ->  Approved
# loan_id = 1258 ->  Approved
# loan_id = 1259 ->  Rejected
# loan_id = 1260 ->  Approved
# loan_id = 1261 ->  Approved
# loan_id = 1262 ->  Rejected
# loan_id = 1263 ->  Approved
# loan_id = 1264 ->  Rejected
# loan_id = 1265 ->  Approved
# loan_id = 1266 ->  Approved
# loan_id = 1267 ->  Approved
# loan_id = 1268 ->  Approved
# loan_id = 1269 ->  Rejected
# loan_id = 1270 ->  Rejected
# loan_id = 1271 ->  Approved
# loan_id = 1272 ->  Rejected
# loan_id = 1273 ->  Rejected
# loan_id = 1274 ->  Approved
# loan_id = 1275 ->  Rejected
# loan_id = 1276 ->  Approved
# loan_id = 1277 ->  Rejected
# loan_id = 1278 ->  Rejected
# loan_id = 1279 ->  Approved
# loan_id = 1280 ->  Approved
# loan_id = 1281 ->  Rejected
# loan_id = 1282 ->  Approved
# loan_id = 1283 ->  Approved
# loan_id = 1284 ->  Rejected
# loan_id = 1285 ->  Rejected
# loan_id = 1286 ->  Rejected
# loan_id = 1287 ->  Rejected
# loan_id = 1288 ->  Approved
# loan_id = 1289 ->  Approved
# loan_id = 1290 ->  Rejected
# loan_id = 1291 ->  Rejected
# loan_id = 1292 ->  Rejected
# loan_id = 1293 ->  Approved
# loan_id = 1294 ->  Approved
# loan_id = 1295 ->  Rejected
# loan_id = 1296 ->  Approved
# loan_id = 1297 ->  Approved
# loan_id = 1298 ->  Rejected
# loan_id = 1299 ->  Approved
# loan_id = 1300 ->  Rejected
# loan_id = 1301 ->  Rejected
# loan_id = 1302 ->  Approved
# loan_id = 1303 ->  Rejected
# loan_id = 1304 ->  Rejected
# loan_id = 1305 ->  Rejected
# loan_id = 1306 ->  Approved
# loan_id = 1307 ->  Approved
# loan_id = 1308 ->  Approved
# loan_id = 1309 ->  Approved
# loan_id = 1310 ->  Approved
# loan_id = 1311 ->  Rejected
# loan_id = 1312 ->  Approved
# loan_id = 1313 ->  Approved
# loan_id = 1314 ->  Approved
# loan_id = 1315 ->  Approved
# loan_id = 1316 ->  Rejected
# loan_id = 1317 ->  Approved
# loan_id = 1318 ->  Approved
# loan_id = 1319 ->  Approved
# loan_id = 1320 ->  Approved
# loan_id = 1321 ->  Approved
# loan_id = 1322 ->  Approved
# loan_id = 1323 ->  Approved
# loan_id = 1324 ->  Approved
# loan_id = 1325 ->  Rejected
# loan_id = 1326 ->  Approved
# loan_id = 1327 ->  Rejected
# loan_id = 1328 ->  Approved
# loan_id = 1329 ->  Rejected
# loan_id = 1330 ->  Rejected
# loan_id = 1331 ->  Approved
# loan_id = 1332 ->  Approved
# loan_id = 1333 ->  Approved
# loan_id = 1334 ->  Approved
# loan_id = 1335 ->  Approved
# loan_id = 1336 ->  Rejected
# loan_id = 1337 ->  Rejected
# loan_id = 1338 ->  Rejected
# loan_id = 1339 ->  Rejected
# loan_id = 1340 ->  Rejected
# loan_id = 1341 ->  Approved
# loan_id = 1342 ->  Approved
# loan_id = 1343 ->  Approved
# loan_id = 1344 ->  Approved
# loan_id = 1345 ->  Approved
# loan_id = 1346 ->  Approved
# loan_id = 1347 ->  Approved
# loan_id = 1348 ->  Rejected
# loan_id = 1349 ->  Rejected
# loan_id = 1350 ->  Rejected
# loan_id = 1351 ->  Rejected
# loan_id = 1352 ->  Approved
# loan_id = 1353 ->  Approved
# loan_id = 1354 ->  Approved
# loan_id = 1355 ->  Approved
# loan_id = 1356 ->  Approved
# loan_id = 1357 ->  Approved
# loan_id = 1358 ->  Rejected
# loan_id = 1359 ->  Approved
# loan_id = 1360 ->  Approved
# loan_id = 1361 ->  Approved
# loan_id = 1362 ->  Rejected
# loan_id = 1363 ->  Approved
# loan_id = 1364 ->  Approved
# loan_id = 1365 ->  Approved
# loan_id = 1366 ->  Rejected
# loan_id = 1367 ->  Rejected
# loan_id = 1368 ->  Approved
# loan_id = 1369 ->  Approved
# loan_id = 1370 ->  Rejected
# loan_id = 1371 ->  Rejected
# loan_id = 1372 ->  Approved
# loan_id = 1373 ->  Approved
# loan_id = 1374 ->  Approved
# loan_id = 1375 ->  Approved
# loan_id = 1376 ->  Approved
# loan_id = 1377 ->  Approved
# loan_id = 1378 ->  Approved
# loan_id = 1379 ->  Approved
# loan_id = 1380 ->  Rejected
# loan_id = 1381 ->  Rejected
# loan_id = 1382 ->  Approved
# loan_id = 1383 ->  Rejected
# loan_id = 1384 ->  Approved
# loan_id = 1385 ->  Rejected
# loan_id = 1386 ->  Rejected
# loan_id = 1387 ->  Rejected
# loan_id = 1388 ->  Approved
# loan_id = 1389 ->  Rejected
# loan_id = 1390 ->  Approved
# loan_id = 1391 ->  Approved
# loan_id = 1392 ->  Approved
# loan_id = 1393 ->  Approved
# loan_id = 1394 ->  Approved
# loan_id = 1395 ->  Approved
# loan_id = 1396 ->  Rejected
# loan_id = 1397 ->  Approved
# loan_id = 1398 ->  Rejected
# loan_id = 1399 ->  Approved
# loan_id = 1400 ->  Approved
# loan_id = 1401 ->  Approved
# loan_id = 1402 ->  Rejected
# loan_id = 1403 ->  Approved
# loan_id = 1404 ->  Rejected
# loan_id = 1405 ->  Rejected
# loan_id = 1406 ->  Approved
# loan_id = 1407 ->  Approved
# loan_id = 1408 ->  Approved
# loan_id = 1409 ->  Approved
# loan_id = 1410 ->  Rejected
# loan_id = 1411 ->  Rejected
# loan_id = 1412 ->  Approved
# loan_id = 1413 ->  Approved
# loan_id = 1414 ->  Approved
# loan_id = 1415 ->  Approved
# loan_id = 1416 ->  Approved
# loan_id = 1417 ->  Rejected
# loan_id = 1418 ->  Rejected
# loan_id = 1419 ->  Approved
# loan_id = 1420 ->  Rejected
# loan_id = 1421 ->  Approved
# loan_id = 1422 ->  Rejected
# loan_id = 1423 ->  Approved
# loan_id = 1424 ->  Rejected
# loan_id = 1425 ->  Rejected
# loan_id = 1426 ->  Rejected
# loan_id = 1427 ->  Rejected
# loan_id = 1428 ->  Approved
# loan_id = 1429 ->  Rejected
# loan_id = 1430 ->  Approved
# loan_id = 1431 ->  Rejected
# loan_id = 1432 ->  Approved
# loan_id = 1433 ->  Approved
# loan_id = 1434 ->  Approved
# loan_id = 1435 ->  Rejected
# loan_id = 1436 ->  Rejected
# loan_id = 1437 ->  Approved
# loan_id = 1438 ->  Approved
# loan_id = 1439 ->  Approved
# loan_id = 1440 ->  Approved
# loan_id = 1441 ->  Rejected
# loan_id = 1442 ->  Rejected
# loan_id = 1443 ->  Approved
# loan_id = 1444 ->  Approved
# loan_id = 1445 ->  Approved
# loan_id = 1446 ->  Approved
# loan_id = 1447 ->  Rejected
# loan_id = 1448 ->  Rejected
# loan_id = 1449 ->  Approved
# loan_id = 1450 ->  Approved
# loan_id = 1451 ->  Approved
# loan_id = 1452 ->  Approved
# loan_id = 1453 ->  Approved
# loan_id = 1454 ->  Rejected
# loan_id = 1455 ->  Rejected
# loan_id = 1456 ->  Rejected
# loan_id = 1457 ->  Approved
# loan_id = 1458 ->  Approved
# loan_id = 1459 ->  Approved
# loan_id = 1460 ->  Rejected
# loan_id = 1461 ->  Approved
# loan_id = 1462 ->  Rejected
# loan_id = 1463 ->  Approved
# loan_id = 1464 ->  Approved
# loan_id = 1465 ->  Approved
# loan_id = 1466 ->  Approved
# loan_id = 1467 ->  Approved
# loan_id = 1468 ->  Approved
# loan_id = 1469 ->  Approved
# loan_id = 1470 ->  Approved
# loan_id = 1471 ->  Rejected
# loan_id = 1472 ->  Rejected
# loan_id = 1473 ->  Approved
# loan_id = 1474 ->  Approved
# loan_id = 1475 ->  Approved
# loan_id = 1476 ->  Rejected
# loan_id = 1477 ->  Approved
# loan_id = 1478 ->  Approved
# loan_id = 1479 ->  Approved
# loan_id = 1480 ->  Approved
# loan_id = 1481 ->  Approved
# loan_id = 1482 ->  Approved
# loan_id = 1483 ->  Approved
# loan_id = 1484 ->  Approved
# loan_id = 1485 ->  Rejected
# loan_id = 1486 ->  Rejected
# loan_id = 1487 ->  Rejected
# loan_id = 1488 ->  Rejected
# loan_id = 1489 ->  Rejected
# loan_id = 1490 ->  Approved
# loan_id = 1491 ->  Approved
# loan_id = 1492 ->  Rejected
# loan_id = 1493 ->  Approved
# loan_id = 1494 ->  Approved
# loan_id = 1495 ->  Rejected
# loan_id = 1496 ->  Rejected
# loan_id = 1497 ->  Rejected
# loan_id = 1498 ->  Rejected
# loan_id = 1499 ->  Approved
# loan_id = 1500 ->  Approved
# loan_id = 1501 ->  Approved
# loan_id = 1502 ->  Rejected
# loan_id = 1503 ->  Rejected
# loan_id = 1504 ->  Approved
# loan_id = 1505 ->  Rejected
# loan_id = 1506 ->  Approved
# loan_id = 1507 ->  Approved
# loan_id = 1508 ->  Rejected
# loan_id = 1509 ->  Approved
# loan_id = 1510 ->  Approved
# loan_id = 1511 ->  Approved
# loan_id = 1512 ->  Approved
# loan_id = 1513 ->  Rejected
# loan_id = 1514 ->  Approved
# loan_id = 1515 ->  Rejected
# loan_id = 1516 ->  Approved
# loan_id = 1517 ->  Approved
# loan_id = 1518 ->  Rejected
# loan_id = 1519 ->  Approved
# loan_id = 1520 ->  Rejected
# loan_id = 1521 ->  Approved
# loan_id = 1522 ->  Approved
# loan_id = 1523 ->  Approved
# loan_id = 1524 ->  Approved
# loan_id = 1525 ->  Approved
# loan_id = 1526 ->  Rejected
# loan_id = 1527 ->  Approved
# loan_id = 1528 ->  Rejected
# loan_id = 1529 ->  Approved
# loan_id = 1530 ->  Approved
# loan_id = 1531 ->  Approved
# loan_id = 1532 ->  Approved
# loan_id = 1533 ->  Approved
# loan_id = 1534 ->  Approved
# loan_id = 1535 ->  Rejected
# loan_id = 1536 ->  Approved
# loan_id = 1537 ->  Approved
# loan_id = 1538 ->  Approved
# loan_id = 1539 ->  Approved
# loan_id = 1540 ->  Rejected
# loan_id = 1541 ->  Approved
# loan_id = 1542 ->  Approved
# loan_id = 1543 ->  Approved
# loan_id = 1544 ->  Rejected
# loan_id = 1545 ->  Approved
# loan_id = 1546 ->  Approved
# loan_id = 1547 ->  Approved
# loan_id = 1548 ->  Rejected
# loan_id = 1549 ->  Approved
# loan_id = 1550 ->  Approved
# loan_id = 1551 ->  Rejected
# loan_id = 1552 ->  Rejected
# loan_id = 1553 ->  Rejected
# loan_id = 1554 ->  Approved
# loan_id = 1555 ->  Approved
# loan_id = 1556 ->  Approved
# loan_id = 1557 ->  Approved
# loan_id = 1558 ->  Approved
# loan_id = 1559 ->  Approved
# loan_id = 1560 ->  Approved
# loan_id = 1561 ->  Rejected
# loan_id = 1562 ->  Approved
# loan_id = 1563 ->  Approved
# loan_id = 1564 ->  Approved
# loan_id = 1565 ->  Approved
# loan_id = 1566 ->  Approved
# loan_id = 1567 ->  Approved
# loan_id = 1568 ->  Rejected
# loan_id = 1569 ->  Rejected
# loan_id = 1570 ->  Approved
# loan_id = 1571 ->  Approved
# loan_id = 1572 ->  Approved
# loan_id = 1573 ->  Approved
# loan_id = 1574 ->  Approved
# loan_id = 1575 ->  Approved
# loan_id = 1576 ->  Approved
# loan_id = 1577 ->  Approved
# loan_id = 1578 ->  Rejected
# loan_id = 1579 ->  Approved
# loan_id = 1580 ->  Rejected
# loan_id = 1581 ->  Approved
# loan_id = 1582 ->  Approved
# loan_id = 1583 ->  Rejected
# loan_id = 1584 ->  Approved
# loan_id = 1585 ->  Approved
# loan_id = 1586 ->  Rejected
# loan_id = 1587 ->  Approved
# loan_id = 1588 ->  Rejected
# loan_id = 1589 ->  Rejected
# loan_id = 1590 ->  Rejected
# loan_id = 1591 ->  Rejected
# loan_id = 1592 ->  Approved
# loan_id = 1593 ->  Approved
# loan_id = 1594 ->  Approved
# loan_id = 1595 ->  Approved
# loan_id = 1596 ->  Approved
# loan_id = 1597 ->  Rejected
# loan_id = 1598 ->  Approved
# loan_id = 1599 ->  Rejected
# loan_id = 1600 ->  Approved
# loan_id = 1601 ->  Approved
# loan_id = 1602 ->  Rejected
# loan_id = 1603 ->  Rejected
# loan_id = 1604 ->  Approved
# loan_id = 1605 ->  Approved
# loan_id = 1606 ->  Approved
# loan_id = 1607 ->  Rejected
# loan_id = 1608 ->  Approved
# loan_id = 1609 ->  Approved
# loan_id = 1610 ->  Rejected
# loan_id = 1611 ->  Approved
# loan_id = 1612 ->  Rejected
# loan_id = 1613 ->  Approved
# loan_id = 1614 ->  Approved
# loan_id = 1615 ->  Rejected
# loan_id = 1616 ->  Rejected
# loan_id = 1617 ->  Approved
# loan_id = 1618 ->  Rejected
# loan_id = 1619 ->  Rejected
# loan_id = 1620 ->  Rejected
# loan_id = 1621 ->  Rejected
# loan_id = 1622 ->  Rejected
# loan_id = 1623 ->  Approved
# loan_id = 1624 ->  Approved
# loan_id = 1625 ->  Rejected
# loan_id = 1626 ->  Approved
# loan_id = 1627 ->  Rejected
# loan_id = 1628 ->  Approved
# loan_id = 1629 ->  Rejected
# loan_id = 1630 ->  Approved
# loan_id = 1631 ->  Rejected
# loan_id = 1632 ->  Approved
# loan_id = 1633 ->  Rejected
# loan_id = 1634 ->  Approved
# loan_id = 1635 ->  Approved
# loan_id = 1636 ->  Approved
# loan_id = 1637 ->  Approved
# loan_id = 1638 ->  Rejected
# loan_id = 1639 ->  Approved
# loan_id = 1640 ->  Rejected
# loan_id = 1641 ->  Approved
# loan_id = 1642 ->  Approved
# loan_id = 1643 ->  Approved
# loan_id = 1644 ->  Approved
# loan_id = 1645 ->  Rejected
# loan_id = 1646 ->  Approved
# loan_id = 1647 ->  Approved
# loan_id = 1648 ->  Approved
# loan_id = 1649 ->  Approved
# loan_id = 1650 ->  Approved
# loan_id = 1651 ->  Approved
# loan_id = 1652 ->  Approved
# loan_id = 1653 ->  Approved
# loan_id = 1654 ->  Approved
# loan_id = 1655 ->  Approved
# loan_id = 1656 ->  Approved
# loan_id = 1657 ->  Rejected
# loan_id = 1658 ->  Approved
# loan_id = 1659 ->  Approved
# loan_id = 1660 ->  Approved
# loan_id = 1661 ->  Approved
# loan_id = 1662 ->  Rejected
# loan_id = 1663 ->  Approved
# loan_id = 1664 ->  Approved
# loan_id = 1665 ->  Rejected
# loan_id = 1666 ->  Approved
# loan_id = 1667 ->  Approved
# loan_id = 1668 ->  Approved
# loan_id = 1669 ->  Approved
# loan_id = 1670 ->  Approved
# loan_id = 1671 ->  Rejected
# loan_id = 1672 ->  Rejected
# loan_id = 1673 ->  Approved
# loan_id = 1674 ->  Approved
# loan_id = 1675 ->  Rejected
# loan_id = 1676 ->  Approved
# loan_id = 1677 ->  Approved
# loan_id = 1678 ->  Rejected
# loan_id = 1679 ->  Approved
# loan_id = 1680 ->  Approved
# loan_id = 1681 ->  Rejected
# loan_id = 1682 ->  Rejected
# loan_id = 1683 ->  Rejected
# loan_id = 1684 ->  Rejected
# loan_id = 1685 ->  Approved
# loan_id = 1686 ->  Approved
# loan_id = 1687 ->  Approved
# loan_id = 1688 ->  Approved
# loan_id = 1689 ->  Approved
# loan_id = 1690 ->  Approved
# loan_id = 1691 ->  Rejected
# loan_id = 1692 ->  Approved
# loan_id = 1693 ->  Approved
# loan_id = 1694 ->  Approved
# loan_id = 1695 ->  Rejected
# loan_id = 1696 ->  Approved
# loan_id = 1697 ->  Approved
# loan_id = 1698 ->  Rejected
# loan_id = 1699 ->  Approved
# loan_id = 1700 ->  Approved
# loan_id = 1701 ->  Approved
# loan_id = 1702 ->  Approved
# loan_id = 1703 ->  Approved
# loan_id = 1704 ->  Rejected
# loan_id = 1705 ->  Rejected
# loan_id = 1706 ->  Rejected
# loan_id = 1707 ->  Rejected
# loan_id = 1708 ->  Rejected
# loan_id = 1709 ->  Rejected
# loan_id = 1710 ->  Approved
# loan_id = 1711 ->  Rejected
# loan_id = 1712 ->  Rejected
# loan_id = 1713 ->  Approved
# loan_id = 1714 ->  Rejected
# loan_id = 1715 ->  Rejected
# loan_id = 1716 ->  Approved
# loan_id = 1717 ->  Rejected
# loan_id = 1718 ->  Approved
# loan_id = 1719 ->  Approved
# loan_id = 1720 ->  Rejected
# loan_id = 1721 ->  Rejected
# loan_id = 1722 ->  Approved
# loan_id = 1723 ->  Rejected
# loan_id = 1724 ->  Rejected
# loan_id = 1725 ->  Approved
# loan_id = 1726 ->  Approved
# loan_id = 1727 ->  Rejected
# loan_id = 1728 ->  Approved
# loan_id = 1729 ->  Rejected
# loan_id = 1730 ->  Approved
# loan_id = 1731 ->  Approved
# loan_id = 1732 ->  Rejected
# loan_id = 1733 ->  Rejected
# loan_id = 1734 ->  Approved
# loan_id = 1735 ->  Rejected
# loan_id = 1736 ->  Approved
# loan_id = 1737 ->  Approved
# loan_id = 1738 ->  Approved
# loan_id = 1739 ->  Approved
# loan_id = 1740 ->  Rejected
# loan_id = 1741 ->  Approved
# loan_id = 1742 ->  Approved
# loan_id = 1743 ->  Approved
# loan_id = 1744 ->  Rejected
# loan_id = 1745 ->  Approved
# loan_id = 1746 ->  Rejected
# loan_id = 1747 ->  Approved
# loan_id = 1748 ->  Rejected
# loan_id = 1749 ->  Rejected
# loan_id = 1750 ->  Approved
# loan_id = 1751 ->  Rejected
# loan_id = 1752 ->  Approved
# ...
# loan_id = 3699 ->  Approved
# loan_id = 3700 ->  Approved
# loan_id = 3701 ->  Rejected
# loan_id = 3702 ->  Rejected
# loan_id = 3703 ->  Approved
# loan_id = 3704 ->  Rejected
# loan_id = 3705 ->  Rejected
# loan_id = 3706 ->  Approved
# loan_id = 3707 ->  Approved
# loan_id = 3708 ->  Rejected
# loan_id = 3709 ->  Approved
# loan_id = 3710 ->  Approved
# loan_id = 3711 ->  Rejected
# loan_id = 3712 ->  Rejected
# loan_id = 3713 ->  Rejected
# loan_id = 3714 ->  Approved
# loan_id = 3715 ->  Approved
# loan_id = 3716 ->  Rejected
# loan_id = 3717 ->  Approved
# loan_id = 3718 ->  Approved
# loan_id = 3719 ->  Rejected
# loan_id = 3720 ->  Approved
# loan_id = 3721 ->  Approved
# loan_id = 3722 ->  Approved
# loan_id = 3723 ->  Approved
# loan_id = 3724 ->  Approved
# loan_id = 3725 ->  Approved
# loan_id = 3726 ->  Approved
# loan_id = 3727 ->  Approved
# loan_id = 3728 ->  Rejected
# loan_id = 3729 ->  Rejected
# loan_id = 3730 ->  Approved
# loan_id = 3731 ->  Approved
# loan_id = 3732 ->  Approved
# loan_id = 3733 ->  Approved
# loan_id = 3734 ->  Rejected
# loan_id = 3735 ->  Rejected
# loan_id = 3736 ->  Approved
# loan_id = 3737 ->  Approved
# loan_id = 3738 ->  Rejected
# loan_id = 3739 ->  Rejected
# loan_id = 3740 ->  Approved
# loan_id = 3741 ->  Rejected
# loan_id = 3742 ->  Approved
# loan_id = 3743 ->  Rejected
# loan_id = 3744 ->  Approved
# loan_id = 3745 ->  Approved
# loan_id = 3746 ->  Approved
# loan_id = 3747 ->  Rejected
# loan_id = 3748 ->  Rejected
# loan_id = 3749 ->  Rejected
# loan_id = 3750 ->  Approved
# loan_id = 3751 ->  Approved
# loan_id = 3752 ->  Approved
# loan_id = 3753 ->  Approved
# loan_id = 3754 ->  Approved
# loan_id = 3755 ->  Approved
# loan_id = 3756 ->  Approved
# loan_id = 3757 ->  Approved
# loan_id = 3758 ->  Rejected
# loan_id = 3759 ->  Approved
# loan_id = 3760 ->  Approved
# loan_id = 3761 ->  Approved
# loan_id = 3762 ->  Rejected
# loan_id = 3763 ->  Approved
# loan_id = 3764 ->  Rejected
# loan_id = 3765 ->  Approved
# loan_id = 3766 ->  Rejected
# loan_id = 3767 ->  Approved
# loan_id = 3768 ->  Rejected
# loan_id = 3769 ->  Rejected
# loan_id = 3770 ->  Approved
# loan_id = 3771 ->  Approved
# loan_id = 3772 ->  Rejected
# loan_id = 3773 ->  Rejected
# loan_id = 3774 ->  Approved
# loan_id = 3775 ->  Approved
# loan_id = 3776 ->  Approved
# loan_id = 3777 ->  Approved
# loan_id = 3778 ->  Approved
# loan_id = 3779 ->  Rejected
# loan_id = 3780 ->  Approved
# loan_id = 3781 ->  Approved
# loan_id = 3782 ->  Rejected
# loan_id = 3783 ->  Rejected
# loan_id = 3784 ->  Approved
# loan_id = 3785 ->  Approved
# loan_id = 3786 ->  Approved
# loan_id = 3787 ->  Approved
# loan_id = 3788 ->  Approved
# loan_id = 3789 ->  Approved
# loan_id = 3790 ->  Rejected
# loan_id = 3791 ->  Rejected
# loan_id = 3792 ->  Approved
# loan_id = 3793 ->  Rejected
# loan_id = 3794 ->  Approved
# loan_id = 3795 ->  Approved
# loan_id = 3796 ->  Approved
# loan_id = 3797 ->  Rejected
# loan_id = 3798 ->  Approved
# loan_id = 3799 ->  Rejected
# loan_id = 3800 ->  Rejected
# loan_id = 3801 ->  Rejected
# loan_id = 3802 ->  Approved
# loan_id = 3803 ->  Approved
# loan_id = 3804 ->  Approved
# loan_id = 3805 ->  Rejected
# loan_id = 3806 ->  Rejected
# loan_id = 3807 ->  Rejected
# loan_id = 3808 ->  Approved
# loan_id = 3809 ->  Approved
# loan_id = 3810 ->  Approved
# loan_id = 3811 ->  Approved
# loan_id = 3812 ->  Approved
# loan_id = 3813 ->  Approved
# loan_id = 3814 ->  Approved
# loan_id = 3815 ->  Approved
# loan_id = 3816 ->  Approved
# loan_id = 3817 ->  Approved
# loan_id = 3818 ->  Approved
# loan_id = 3819 ->  Approved
# loan_id = 3820 ->  Approved
# loan_id = 3821 ->  Approved
# loan_id = 3822 ->  Rejected
# loan_id = 3823 ->  Approved
# loan_id = 3824 ->  Approved
# loan_id = 3825 ->  Approved
# loan_id = 3826 ->  Approved
# loan_id = 3827 ->  Rejected
# loan_id = 3828 ->  Rejected
# loan_id = 3829 ->  Rejected
# loan_id = 3830 ->  Approved
# loan_id = 3831 ->  Approved
# loan_id = 3832 ->  Rejected
# loan_id = 3833 ->  Approved
# loan_id = 3834 ->  Rejected
# loan_id = 3835 ->  Approved
# loan_id = 3836 ->  Approved
# loan_id = 3837 ->  Rejected
# loan_id = 3838 ->  Rejected
# loan_id = 3839 ->  Rejected
# loan_id = 3840 ->  Approved
# loan_id = 3841 ->  Rejected
# loan_id = 3842 ->  Approved
# loan_id = 3843 ->  Rejected
# loan_id = 3844 ->  Approved
# loan_id = 3845 ->  Approved
# loan_id = 3846 ->  Approved
# loan_id = 3847 ->  Approved
# loan_id = 3848 ->  Approved
# loan_id = 3849 ->  Approved
# loan_id = 3850 ->  Approved
# loan_id = 3851 ->  Approved
# loan_id = 3852 ->  Approved
# loan_id = 3853 ->  Approved
# loan_id = 3854 ->  Approved
# loan_id = 3855 ->  Approved
# loan_id = 3856 ->  Approved
# loan_id = 3857 ->  Approved
# loan_id = 3858 ->  Approved
# loan_id = 3859 ->  Rejected
# loan_id = 3860 ->  Rejected
# loan_id = 3861 ->  Approved
# loan_id = 3862 ->  Approved
# loan_id = 3863 ->  Rejected
# loan_id = 3864 ->  Rejected
# loan_id = 3865 ->  Approved
# loan_id = 3866 ->  Rejected
# loan_id = 3867 ->  Approved
# loan_id = 3868 ->  Approved
# loan_id = 3869 ->  Approved
# loan_id = 3870 ->  Rejected
# loan_id = 3871 ->  Approved
# loan_id = 3872 ->  Rejected
# loan_id = 3873 ->  Approved
# loan_id = 3874 ->  Rejected
# loan_id = 3875 ->  Rejected
# loan_id = 3876 ->  Approved
# loan_id = 3877 ->  Approved
# loan_id = 3878 ->  Approved
# loan_id = 3879 ->  Approved
# loan_id = 3880 ->  Rejected
# loan_id = 3881 ->  Approved
# loan_id = 3882 ->  Rejected
# loan_id = 3883 ->  Approved
# loan_id = 3884 ->  Rejected
# loan_id = 3885 ->  Rejected
# loan_id = 3886 ->  Approved
# loan_id = 3887 ->  Approved
# loan_id = 3888 ->  Approved
# loan_id = 3889 ->  Approved
# loan_id = 3890 ->  Approved
# loan_id = 3891 ->  Approved
# loan_id = 3892 ->  Approved
# loan_id = 3893 ->  Approved
# loan_id = 3894 ->  Rejected
# loan_id = 3895 ->  Rejected
# loan_id = 3896 ->  Rejected
# loan_id = 3897 ->  Approved
# loan_id = 3898 ->  Approved
# loan_id = 3899 ->  Approved
# loan_id = 3900 ->  Approved
# loan_id = 3901 ->  Rejected
# loan_id = 3902 ->  Rejected
# loan_id = 3903 ->  Approved
# loan_id = 3904 ->  Approved
# loan_id = 3905 ->  Rejected
# loan_id = 3906 ->  Approved
# loan_id = 3907 ->  Approved
# loan_id = 3908 ->  Rejected
# loan_id = 3909 ->  Approved
# loan_id = 3910 ->  Approved
# loan_id = 3911 ->  Rejected
# loan_id = 3912 ->  Rejected
# loan_id = 3913 ->  Approved
# loan_id = 3914 ->  Rejected
# loan_id = 3915 ->  Rejected
# loan_id = 3916 ->  Approved
# loan_id = 3917 ->  Approved
# loan_id = 3918 ->  Rejected
# loan_id = 3919 ->  Approved
# loan_id = 3920 ->  Rejected
# loan_id = 3921 ->  Approved
# loan_id = 3922 ->  Rejected
# loan_id = 3923 ->  Approved
# loan_id = 3924 ->  Approved
# loan_id = 3925 ->  Approved
# loan_id = 3926 ->  Approved
# loan_id = 3927 ->  Approved
# loan_id = 3928 ->  Approved
# loan_id = 3929 ->  Rejected
# loan_id = 3930 ->  Approved
# loan_id = 3931 ->  Rejected
# loan_id = 3932 ->  Approved
# loan_id = 3933 ->  Approved
# loan_id = 3934 ->  Approved
# loan_id = 3935 ->  Rejected
# loan_id = 3936 ->  Rejected
# loan_id = 3937 ->  Rejected
# loan_id = 3938 ->  Approved
# loan_id = 3939 ->  Approved
# loan_id = 3940 ->  Approved
# loan_id = 3941 ->  Approved
# loan_id = 3942 ->  Rejected
# loan_id = 3943 ->  Approved
# loan_id = 3944 ->  Approved
# loan_id = 3945 ->  Approved
# loan_id = 3946 ->  Approved
# loan_id = 3947 ->  Approved
# loan_id = 3948 ->  Rejected
# loan_id = 3949 ->  Approved
# loan_id = 3950 ->  Rejected
# loan_id = 3951 ->  Approved
# loan_id = 3952 ->  Approved
# loan_id = 3953 ->  Approved
# loan_id = 3954 ->  Approved
# loan_id = 3955 ->  Approved
# loan_id = 3956 ->  Rejected
# loan_id = 3957 ->  Approved
# loan_id = 3958 ->  Rejected
# loan_id = 3959 ->  Approved
# loan_id = 3960 ->  Approved
# loan_id = 3961 ->  Rejected
# loan_id = 3962 ->  Approved
# loan_id = 3963 ->  Approved
# loan_id = 3964 ->  Approved
# loan_id = 3965 ->  Approved
# loan_id = 3966 ->  Approved
# loan_id = 3967 ->  Approved
# loan_id = 3968 ->  Approved
# loan_id = 3969 ->  Approved
# loan_id = 3970 ->  Rejected
# loan_id = 3971 ->  Approved
# loan_id = 3972 ->  Rejected
# loan_id = 3973 ->  Approved
# loan_id = 3974 ->  Approved
# loan_id = 3975 ->  Approved
# loan_id = 3976 ->  Approved
# loan_id = 3977 ->  Rejected
# loan_id = 3978 ->  Rejected
# loan_id = 3979 ->  Approved
# loan_id = 3980 ->  Approved
# loan_id = 3981 ->  Approved
# loan_id = 3982 ->  Approved
# loan_id = 3983 ->  Approved
# loan_id = 3984 ->  Rejected
# loan_id = 3985 ->  Rejected
# loan_id = 3986 ->  Approved
# loan_id = 3987 ->  Rejected
# loan_id = 3988 ->  Rejected
# loan_id = 3989 ->  Approved
# loan_id = 3990 ->  Rejected
# loan_id = 3991 ->  Rejected
# loan_id = 3992 ->  Rejected
# loan_id = 3993 ->  Approved
# loan_id = 3994 ->  Approved
# loan_id = 3995 ->  Approved
# loan_id = 3996 ->  Approved
# loan_id = 3997 ->  Rejected
# loan_id = 3998 ->  Rejected
# loan_id = 3999 ->  Rejected
# loan_id = 4000 ->  Rejected
# loan_id = 4001 ->  Approved
# loan_id = 4002 ->  Rejected
# loan_id = 4003 ->  Rejected
# loan_id = 4004 ->  Approved
# loan_id = 4005 ->  Approved
# loan_id = 4006 ->  Rejected
# loan_id = 4007 ->  Approved
# loan_id = 4008 ->  Approved
# loan_id = 4009 ->  Approved
# loan_id = 4010 ->  Approved
# loan_id = 4011 ->  Rejected
# loan_id = 4012 ->  Approved
# loan_id = 4013 ->  Approved
# loan_id = 4014 ->  Approved
# loan_id = 4015 ->  Approved
# loan_id = 4016 ->  Approved
# loan_id = 4017 ->  Approved
# loan_id = 4018 ->  Approved
# loan_id = 4019 ->  Approved
# loan_id = 4020 ->  Approved
# loan_id = 4021 ->  Approved
# loan_id = 4022 ->  Approved
# loan_id = 4023 ->  Rejected
# loan_id = 4024 ->  Approved
# loan_id = 4025 ->  Rejected
# loan_id = 4026 ->  Rejected
# loan_id = 4027 ->  Approved
# loan_id = 4028 ->  Rejected
# loan_id = 4029 ->  Rejected
# loan_id = 4030 ->  Approved
# loan_id = 4031 ->  Rejected
# loan_id = 4032 ->  Approved
# loan_id = 4033 ->  Approved
# loan_id = 4034 ->  Approved
# loan_id = 4035 ->  Approved
# loan_id = 4036 ->  Approved
# loan_id = 4037 ->  Approved
# loan_id = 4038 ->  Approved
# loan_id = 4039 ->  Rejected
# loan_id = 4040 ->  Rejected
# loan_id = 4041 ->  Approved
# loan_id = 4042 ->  Rejected
# loan_id = 4043 ->  Approved
# loan_id = 4044 ->  Rejected
# loan_id = 4045 ->  Approved
# loan_id = 4046 ->  Approved
# loan_id = 4047 ->  Approved
# loan_id = 4048 ->  Rejected
# loan_id = 4049 ->  Approved
# loan_id = 4050 ->  Rejected
# loan_id = 4051 ->  Rejected
# loan_id = 4052 ->  Approved
# loan_id = 4053 ->  Rejected
# loan_id = 4054 ->  Approved
# loan_id = 4055 ->  Approved
# loan_id = 4056 ->  Rejected
# loan_id = 4057 ->  Rejected
# loan_id = 4058 ->  Approved
# loan_id = 4059 ->  Rejected
# loan_id = 4060 ->  Approved
# loan_id = 4061 ->  Rejected
# loan_id = 4062 ->  Rejected
# loan_id = 4063 ->  Rejected
# loan_id = 4064 ->  Approved
# loan_id = 4065 ->  Approved
# loan_id = 4066 ->  Approved
# loan_id = 4067 ->  Rejected
# loan_id = 4068 ->  Approved
# loan_id = 4069 ->  Rejected
# loan_id = 4070 ->  Approved
# loan_id = 4071 ->  Approved
# loan_id = 4072 ->  Approved
# loan_id = 4073 ->  Approved
# loan_id = 4074 ->  Approved
# loan_id = 4075 ->  Approved
# loan_id = 4076 ->  Approved
# loan_id = 4077 ->  Rejected
# loan_id = 4078 ->  Approved
# loan_id = 4079 ->  Approved
# loan_id = 4080 ->  Approved
# loan_id = 4081 ->  Approved
# loan_id = 4082 ->  Approved
# loan_id = 4083 ->  Approved
# loan_id = 4084 ->  Approved
# loan_id = 4085 ->  Rejected
# loan_id = 4086 ->  Approved
# loan_id = 4087 ->  Rejected
# loan_id = 4088 ->  Approved
# loan_id = 4089 ->  Rejected
# loan_id = 4090 ->  Approved
# loan_id = 4091 ->  Approved
# loan_id = 4092 ->  Rejected
# loan_id = 4093 ->  Approved
# loan_id = 4094 ->  Approved
# loan_id = 4095 ->  Rejected
# loan_id = 4096 ->  Rejected
# loan_id = 4097 ->  Approved
# loan_id = 4098 ->  Approved
# loan_id = 4099 ->  Approved
# loan_id = 4100 ->  Rejected
# loan_id = 4101 ->  Approved
# loan_id = 4102 ->  Approved
# loan_id = 4103 ->  Approved
# loan_id = 4104 ->  Approved
# loan_id = 4105 ->  Approved
# loan_id = 4106 ->  Approved
# loan_id = 4107 ->  Approved
# loan_id = 4108 ->  Approved
# loan_id = 4109 ->  Rejected
# loan_id = 4110 ->  Rejected
# loan_id = 4111 ->  Approved
# loan_id = 4112 ->  Rejected
# loan_id = 4113 ->  Approved
# loan_id = 4114 ->  Approved
# loan_id = 4115 ->  Approved
# loan_id = 4116 ->  Approved
# loan_id = 4117 ->  Approved
# loan_id = 4118 ->  Rejected
# loan_id = 4119 ->  Approved
# loan_id = 4120 ->  Rejected
# loan_id = 4121 ->  Approved
# loan_id = 4122 ->  Rejected
# loan_id = 4123 ->  Rejected
# loan_id = 4124 ->  Rejected
# loan_id = 4125 ->  Approved
# loan_id = 4126 ->  Rejected
# loan_id = 4127 ->  Approved
# loan_id = 4128 ->  Rejected
# loan_id = 4129 ->  Rejected
# loan_id = 4130 ->  Rejected
# loan_id = 4131 ->  Approved
# loan_id = 4132 ->  Approved
# loan_id = 4133 ->  Rejected
# loan_id = 4134 ->  Rejected
# loan_id = 4135 ->  Approved
# loan_id = 4136 ->  Approved
# loan_id = 4137 ->  Approved
# loan_id = 4138 ->  Approved
# loan_id = 4139 ->  Rejected
# loan_id = 4140 ->  Approved
# loan_id = 4141 ->  Approved
# loan_id = 4142 ->  Rejected
# loan_id = 4143 ->  Approved
# loan_id = 4144 ->  Rejected
# loan_id = 4145 ->  Approved
# loan_id = 4146 ->  Rejected
# loan_id = 4147 ->  Approved
# loan_id = 4148 ->  Approved
# loan_id = 4149 ->  Approved
# loan_id = 4150 ->  Approved
# loan_id = 4151 ->  Rejected
# loan_id = 4152 ->  Approved
# loan_id = 4153 ->  Approved
# loan_id = 4154 ->  Approved
# loan_id = 4155 ->  Approved
# loan_id = 4156 ->  Approved
# loan_id = 4157 ->  Rejected
# loan_id = 4158 ->  Rejected
# loan_id = 4159 ->  Approved
# loan_id = 4160 ->  Approved
# loan_id = 4161 ->  Rejected
# loan_id = 4162 ->  Approved
# loan_id = 4163 ->  Approved
# loan_id = 4164 ->  Approved
# loan_id = 4165 ->  Approved
# loan_id = 4166 ->  Approved
# loan_id = 4167 ->  Approved
# loan_id = 4168 ->  Approved
# loan_id = 4169 ->  Rejected
# loan_id = 4170 ->  Approved
# loan_id = 4171 ->  Approved
# loan_id = 4172 ->  Approved
# loan_id = 4173 ->  Approved
# loan_id = 4174 ->  Rejected
# loan_id = 4175 ->  Approved
# loan_id = 4176 ->  Rejected
# loan_id = 4177 ->  Rejected
# loan_id = 4178 ->  Approved
# loan_id = 4179 ->  Approved
# loan_id = 4180 ->  Approved
# loan_id = 4181 ->  Rejected
# loan_id = 4182 ->  Rejected
# loan_id = 4183 ->  Approved
# loan_id = 4184 ->  Rejected
# loan_id = 4185 ->  Approved
# loan_id = 4186 ->  Approved
# loan_id = 4187 ->  Approved
# loan_id = 4188 ->  Rejected
# loan_id = 4189 ->  Rejected
# loan_id = 4190 ->  Approved
# loan_id = 4191 ->  Rejected
# loan_id = 4192 ->  Rejected
# loan_id = 4193 ->  Approved
# loan_id = 4194 ->  Rejected
# loan_id = 4195 ->  Approved
# loan_id = 4196 ->  Approved
# loan_id = 4197 ->  Approved
# loan_id = 4198 ->  Approved
# loan_id = 4199 ->  Rejected
# loan_id = 4200 ->  Approved
# loan_id = 4201 ->  Rejected
# loan_id = 4202 ->  Approved
# loan_id = 4203 ->  Approved
# loan_id = 4204 ->  Rejected
# loan_id = 4205 ->  Approved
# loan_id = 4206 ->  Approved
# loan_id = 4207 ->  Approved
# loan_id = 4208 ->  Rejected
# loan_id = 4209 ->  Approved
# loan_id = 4210 ->  Rejected
# loan_id = 4211 ->  Approved
# loan_id = 4212 ->  Approved
# loan_id = 4213 ->  Approved
# loan_id = 4214 ->  Approved
# loan_id = 4215 ->  Approved
# loan_id = 4216 ->  Rejected
# loan_id = 4217 ->  Approved
# loan_id = 4218 ->  Approved
# loan_id = 4219 ->  Approved
# loan_id = 4220 ->  Approved
# loan_id = 4221 ->  Approved
# loan_id = 4222 ->  Rejected
# loan_id = 4223 ->  Rejected
# loan_id = 4224 ->  Approved
# loan_id = 4225 ->  Approved
# loan_id = 4226 ->  Approved
# loan_id = 4227 ->  Approved
# loan_id = 4228 ->  Approved
# loan_id = 4229 ->  Rejected
# loan_id = 4230 ->  Approved
# loan_id = 4231 ->  Approved
# loan_id = 4232 ->  Approved
# loan_id = 4233 ->  Approved
# loan_id = 4234 ->  Approved
# loan_id = 4235 ->  Approved
# loan_id = 4236 ->  Approved
# loan_id = 4237 ->  Rejected
# loan_id = 4238 ->  Rejected
# loan_id = 4239 ->  Approved
# loan_id = 4240 ->  Rejected
# loan_id = 4241 ->  Approved
# loan_id = 4242 ->  Approved
# loan_id = 4243 ->  Approved
# loan_id = 4244 ->  Approved
# loan_id = 4245 ->  Approved
# loan_id = 4246 ->  Approved
# loan_id = 4247 ->  Approved
# loan_id = 4248 ->  Approved
# loan_id = 4249 ->  Rejected
# loan_id = 4250 ->  Approved
# loan_id = 4251 ->  Approved
# loan_id = 4252 ->  Approved
# loan_id = 4253 ->  Rejected
# loan_id = 4254 ->  Approved
# loan_id = 4255 ->  Rejected
# loan_id = 4256 ->  Rejected
# loan_id = 4257 ->  Rejected
# loan_id = 4258 ->  Rejected
# loan_id = 4259 ->  Rejected
# loan_id = 4260 ->  Rejected
# loan_id = 4261 ->  Approved
# loan_id = 4262 ->  Approved
# loan_id = 4263 ->  Rejected
# loan_id = 4264 ->  Approved
# loan_id = 4265 ->  Rejected
# loan_id = 4266 ->  Approved
# loan_id = 4267 ->  Rejected
# loan_id = 4268 ->  Approved
# loan_id = 4269 ->  Approved

# %%
sample = {
    "no_of_dependents": 2,
    "education": "Graduate",
    "self_employed": "No",
    "income_annum": 9600000,
    "loan_amount": 29900000,
    "loan_term": 12,
    "cibil_score": 778,
    "residential_assets_value": 2400000,
    "commercial_assets_value": 17600000,
    "luxury_assets_value": 22700000,
    "bank_asset_value": 8000000
}

# %%
print("\nPrediction for sample:", predict(decision_tree, sample))
# Out:
# Prediction for sample: Unknown

# %%
df.head(4)
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
#
#    loan_status
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
