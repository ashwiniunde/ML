# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, export_text

# %%
# 1. Create the dataset (14 rows)
data = {
    'Age': ['<21','<21','21-35','>35','>35','>35','21-35','<21','<21','>35','<21','21-35','21-35','>35',],
    'Income': ['High','High','High','Medium','Low','Low','Low','Medium','Low','Medium','Medium','Medium','High','Medium'],
    'Gender': ['Male','Male','Male','Male','Female','Female','Female','Male','Female','Female','Female','Male','Female','Male'],
    'MaritalStatus': ['Single','Married','Single','Single','Single','Married','Married','Single','Married','Single','Married','Married','Single','Married'],
    'Buys': ['No','No','Yes','Yes','Yes','No','Yes','No','Yes','Yes','Yes','Yes','Yes','No']
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Age  Income  Gender MaritalStatus Buys
# 0     <21    High    Male        Single   No
# 1     <21    High    Male       Married   No
# 2   21-35    High    Male        Single  Yes
# 3     >35  Medium    Male        Single  Yes
# 4     >35     Low  Female        Single  Yes
# 5     >35     Low  Female       Married   No
# 6   21-35     Low  Female       Married  Yes
# 7     <21  Medium    Male        Single   No
# 8     <21     Low  Female       Married  Yes
# 9     >35  Medium  Female        Single  Yes
# 10    <21  Medium  Female       Married  Yes
# 11  21-35  Medium    Male       Married  Yes
# 12  21-35    High  Female        Single  Yes
# 13    >35  Medium    Male       Married   No

# %%
# 2. Encode categorical variables into numbers
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in df.columns:
    df[col] = le.fit_transform(df[col])

# %%
# 3. Features (X) and Target (y)
X = df.drop('Buys', axis=1)
y = df['Buys']

# %%
# 4. Train Decision Tree Classifier
clf = DecisionTreeClassifier(criterion='entropy')
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
# 5. Show tree rules
tree_rules = export_text(clf, feature_names=list(X.columns))
print(tree_rules)
# Out:
# |--- Age <= 0.50
# |   |--- class: 1
# |--- Age >  0.50
# |   |--- Gender <= 0.50
# |   |   |--- MaritalStatus <= 0.50
# |   |   |   |--- Age <= 1.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- Age >  1.50
# |   |   |   |   |--- class: 0
# |   |   |--- MaritalStatus >  0.50
# |   |   |   |--- class: 1
# |   |--- Gender >  0.50
# |   |   |--- Age <= 1.50
# |   |   |   |--- class: 0
# |   |   |--- Age >  1.50
# |   |   |   |--- MaritalStatus <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- MaritalStatus >  0.50
# |   |   |   |   |--- class: 1

# %%
# 6. Test Data: [Age <21, Income=Low, Gender=Female, MaritalStatus=Married]
# Encode with same LabelEncoder logic
test_data = pd.DataFrame([['>35','Medium','Male','Married']], columns=['Age','Income','Gender','MaritalStatus'])

# %%
# Apply label encoding column-wise
for col in test_data.columns:
    test_data[col] = le.fit_transform(test_data[col])  #  Better way: use separate encoders per column

# %%
# Predict
prediction = clf.predict(test_data)
print("Prediction for test data:", "Yes (Buys)" if prediction[0]==1 else "No (Does not buy)")
# Out:
# Prediction for test data: Yes (Buys)

# %%
df.to_csv("data.csv", index=False)

# %%
#import packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#reading Dataset
dataset=pd.read_csv("data.csv")
X=dataset.iloc[:,:-1]
# Target (last column)
y = dataset.iloc[:, -1].values

# %%
# Perform Label encoding
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()
X = X.apply(LabelEncoder().fit_transform)

# %%
print("Features after encoding:\n", X)
# Out:
# Features after encoding:
#      Age  Income  Gender  MaritalStatus
# 0     1       0       1              1
# 1     1       0       1              0
# 2     0       0       1              1
# 3     2       2       1              1
# 4     2       1       0              1
# 5     2       1       0              0
# 6     0       1       0              0
# 7     1       2       1              1
# 8     1       1       0              0
# 9     2       2       0              1
# 10    1       2       0              0
# 11    0       2       1              0
# 12    0       0       0              1
# 13    2       2       1              0

# %%
# Train Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
regressor = DecisionTreeClassifier()
regressor.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
# Predict value for a new input
X_in = np.array([1,1,0,0])   # sample input
y_pred = regressor.predict([X_in])
print("Prediction:", y_pred)
# Out:
# Prediction: [1]
# C:\Users\ashwi\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
# Visualize tree
from io import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus

# %%
# !pip install pydotplus
# Out:
# Collecting pydotplus
#   Downloading pydotplus-2.0.2.tar.gz (278 kB)
#      ---------------------------------------- 0.0/278.7 kB ? eta -:--:--
#      -- ---------------------------------- 20.5/278.7 kB 330.3 kB/s eta 0:00:01
#      -- ---------------------------------- 20.5/278.7 kB 330.3 kB/s eta 0:00:01
#      -- ---------------------------------- 20.5/278.7 kB 330.3 kB/s eta 0:00:01
#      ---- -------------------------------- 30.7/278.7 kB 119.1 kB/s eta 0:00:03
#      --------- --------------------------- 71.7/278.7 kB 281.8 kB/s eta 0:00:01
#      --------- --------------------------- 71.7/278.7 kB 281.8 kB/s eta 0:00:01
#      --------- --------------------------- 71.7/278.7 kB 281.8 kB/s eta 0:00:01
#      --------- --------------------------- 71.7/278.7 kB 281.8 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 327.9 kB/s eta 0:00:01
#      ------------------- ---------------- 153.6/278.7 kB 339.7 kB/s eta 0:00:01
#      ------------------- ---------------- 153.6/278.7 kB 339.7 kB/s eta 0:00:01
#      ------------------- ---------------- 153.6/278.7 kB 339.7 kB/s eta 0:00:01
#      -------------------------- --------- 204.8/278.7 kB 328.1 kB/s eta 0:00:01
#      -------------------------- --------- 204.8/278.7 kB 328.1 kB/s eta 0:00:01
#      -------------------------- --------- 204.8/278.7 kB 328.1 kB/s eta 0:00:01
#      -------------------------- --------- 204.8/278.7 kB 328.1 kB/s eta 0:00:01
#      --------------------------------- -- 256.0/278.7 kB 308.4 kB/s eta 0:00:01
#      -----------------------------------  276.5/278.7 kB 334.1 kB/s eta 0:00:01
#      ------------------------------------ 278.7/278.7 kB 318.4 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\ashwi\anaconda3\lib\site-packages (from pydotplus) (3.0.9)
# Building wheels for collected packages: pydotplus
#   Building wheel for pydotplus (setup.py): started
#   Building wheel for pydotplus (setup.py): finished with status 'done'
#   Created wheel for pydotplus: filename=pydotplus-2.0.2-py3-none-any.whl size=24574 sha256=843fef8fc7724394588256f0c8dcb9703a89a7789de25092e76279b1a6118c20
#   Stored in directory: c:\users\ashwi\appdata\local\pip\cache\wheels\bd\ce\e8\ff9d9c699514922f57caa22fbd55b0a32761114b4c4acc9e03
# Successfully built pydotplus
# Installing collected packages: pydotplus
# Successfully installed pydotplus-2.0.2

# %%
dot_data = StringIO()
export_graphviz(regressor, out_file=dot_data, feature_names=X.columns,
                filled=True, rounded=True, special_characters=True)

# %%
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('Decision_Tree.png')
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# Cell In[42], line 2
#       1 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# ----> 2 graph.write_png('Decision_Tree.png')
#       3 Image(graph.create_png())
#
# File ~\anaconda3\Lib\site-packages\pydotplus\graphviz.py:1810, in Dot.__init__.<locals>.<lambda>(path, f, prog)
#    1800     f.__doc__ = (
#    1801         '''Refer to the docstring accompanying the'''
#    1802         ''''create' method for more information.'''
#    1803     )
#    1805 for frmt in self.formats + ['raw']:
#    1806     self.__setattr__(
#    1807         'write_' + frmt,
#    1808         lambda path,
#    1809         f=frmt,
# -> 1810         prog=self.prog: self.write(path, format=f, prog=prog)
#    1811     )
#    1813     f = self.__dict__['write_' + frmt]
#    1814     f.__doc__ = (
#    1815         '''Refer to the docstring accompanying the'''
#    1816         ''''write' method for more information.'''
#    1817     )
#
# File ~\anaconda3\Lib\site-packages\pydotplus\graphviz.py:1918, in Dot.write(self, path, prog, format)
#    1915         fobj.write(data)
#    1917     else:
# -> 1918         fobj.write(self.create(prog, format))
#    1919 finally:
#    1920     if close:
#
# File ~\anaconda3\Lib\site-packages\pydotplus\graphviz.py:1959, in Dot.create(self, prog, format)
#    1957     self.progs = find_graphviz()
#    1958     if self.progs is None:
# -> 1959         raise InvocationException(
#    1960             'GraphViz\'s executables not found')
#    1962 if prog not in self.progs:
#    1963     raise InvocationException(
#    1964         'GraphViz\'s executable "%s" not found' % prog)
#
# InvocationException: GraphViz's executables not found
